# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image
import torch
from torchvision import datasets, models, transforms
import torch.nn as nn
from torch.nn import functional as F
import torch.optim as optim
import torchvision

# %%
original_folder = "C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/lisat_gaze_data_mixed/train"

# %% [markdown]
# # Splitting Training & Validation Dataset

# %%
import os
train_folder ="C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/train"
def count_files_in_folders(directory):
  for root, dirs, files in os.walk(directory):
    print(f"Folder: {root}")
    file_count = len(files)
    print(f"Number of files: {file_count}")
    print("-" * 20)
count_files_in_folders(train_folder)
# Out:
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/train
# Number of files: 0
# --------------------
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/train\Eyes Closed
# Number of files: 1737
# --------------------
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/train\Forward
# Number of files: 2824
# --------------------
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/train\Left Mirror
# Number of files: 2600
# --------------------
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/train\Radio
# Number of files: 2820
# --------------------
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/train\Rearview
# Number of files: 2694
# --------------------
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/train\Right Mirror
# Number of files: 2512
# --------------------
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/train\Shoulder
# Number of files: 4658
# --------------------
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/train\Speedometer
# Number of files: 2711
# --------------------

# %%
val_folder ="C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/val"
def count_files_in_folders(directory):
  for root, dirs, files in os.walk(directory):
    print(f"Folder: {root}")
    file_count = len(files)
    print(f"Number of files: {file_count}")
    print("-" * 20)
count_files_in_folders(val_folder)
# Out:
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/val
# Number of files: 0
# --------------------
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/val\Eyes Closed
# Number of files: 501
# --------------------
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/val\Forward
# Number of files: 705
# --------------------
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/val\Left Mirror
# Number of files: 646
# --------------------
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/val\Radio
# Number of files: 685
# --------------------
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/val\Rearview
# Number of files: 687
# --------------------
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/val\Right Mirror
# Number of files: 628
# --------------------
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/val\Shoulder
# Number of files: 1256
# --------------------
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/val\Speedometer
# Number of files: 759
# --------------------

# %%
input_path='C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/'

# %%
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])

data_transforms = {
    'train':
    transforms.Compose([
        transforms.Resize((224,224)),
        transforms.RandomAffine(0, shear=10, scale=(0.8,1.2)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        normalize
    ]),
    'validation':
    transforms.Compose([
        transforms.Resize((224,224)),
        transforms.ToTensor(), #for parallel computations
        normalize
    ]),
}

#train_subset_size = int(0.4 * len(datasets.ImageFolder(input_path + 'train_1250', transform=data_transforms['train']))) #testing hashelha b3den

image_datasets = {
    'train':
    datasets.ImageFolder(input_path + 'split_new/train', data_transforms['train']),
    'validation':
    datasets.ImageFolder(input_path + 'split_new/val', data_transforms['validation'])
}

dataloaders = {
    'train':
    torch.utils.data.DataLoader(image_datasets['train'],
                                batch_size=32,
                                shuffle=True,
                                num_workers=2),  # for now 2
    'validation':
    torch.utils.data.DataLoader(image_datasets['validation'],
                                batch_size=32,
                                shuffle=False,
                                num_workers=2)  # for Kaggle
}

# %%
print("Train dataset size:", len(image_datasets['train']))
print("Validation dataset size:", len(image_datasets['validation']))
# Out:
# Train dataset size: 22556
# Validation dataset size: 5867

# %%
# from torch.utils.data import random_split

# normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
#                                  std=[0.229, 0.224, 0.225])

# data_transforms = {
#     'train':
#     transforms.Compose([
#         transforms.Resize((224,224)),
#         transforms.RandomAffine(0, shear=10, scale=(0.8,1.2)),
#         transforms.RandomHorizontalFlip(),
#         transforms.ToTensor(),
#         normalize
#     ])
# }
# full_dataset = datasets.ImageFolder(input_path + 
#                                     '/train', 
#                                     data_transforms['train'])

# # Calculate the sizes of the training and validation sets
# train_size = int(0.8 * len(full_dataset))
# val_size = len(full_dataset) - train_size

# # Split the dataset into training and validation sets
# train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

# # Create data loaders for training and validation sets
# dataloaders = {
#     'train': torch.utils.data.DataLoader(train_dataset,
#                                          batch_size=32,
#                                          shuffle=True,
#                                          num_workers=2),
#     'validation': torch.utils.data.DataLoader(val_dataset,
#                                               batch_size=32,
#                                               shuffle=True,
#                                               num_workers=2)
# }
# print(len(train_dataset))
# print(len(val_dataset))

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
model =torchvision.models.mobilenet_v3_small(pretrained=True).to(device)
model
# Out:
# C:\Users\AS-GP\AppData\Local\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\AS-GP\AppData\Local\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V3_Small_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V3_Small_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# MobileNetV3(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): Hardswish()
#     )
#     (1): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=16, bias=False)
#           (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(16, 8, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(8, 16, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (2): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(72, 72, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=72, bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (3): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(88, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(88, 88, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=88, bias=False)
#           (1): BatchNorm2d(88, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(88, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (4): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(96, 96, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=96, bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(96, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (5): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(240, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 240, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (6): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(240, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 240, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (7): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(120, 32, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(32, 120, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(120, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (8): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(48, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(40, 144, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(144, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (9): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=288, bias=False)
#           (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(288, 72, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(72, 288, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(288, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (10): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(576, 144, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(144, 576, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (11): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(576, 144, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(144, 576, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (12): Conv2dNormActivation(
#       (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): Hardswish()
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Linear(in_features=576, out_features=1024, bias=True)
#     (1): Hardswish()
#     (2): Dropout(p=0.2, inplace=True)
#     (3): Linear(in_features=1024, out_features=1000, bias=True)
#   )
# )

# %%
model =torchvision.models.mobilenet_v3_small(pretrained=True).to(device)

for param in model.parameters():
    param.requires_grad = False

# Define constants
NUM_CLASSES = 8
INPUT_FEATURES = 576
HIDDEN_FEATURES = 1024
OUTPUT_FEATURES = 1280

# Define the custom classifier
classifier = nn.Sequential(
    nn.Linear(INPUT_FEATURES, HIDDEN_FEATURES, bias=True),
    nn.Hardswish(),
    nn.Dropout(p=0.2, inplace=True),
    nn.Linear(HIDDEN_FEATURES, OUTPUT_FEATURES, bias=True),
    nn.Linear(OUTPUT_FEATURES, NUM_CLASSES, bias=True),  # Output layer with 8 classes
    #nn.Softmax(dim=1)
)

# Replace the default classifier with the custom one
model.classifier = classifier

model
# Out:
# C:\Users\AS-GP\AppData\Local\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\AS-GP\AppData\Local\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V3_Small_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V3_Small_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# MobileNetV3(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): Hardswish()
#     )
#     (1): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=16, bias=False)
#           (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(16, 8, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(8, 16, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (2): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(72, 72, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=72, bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (3): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(88, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(88, 88, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=88, bias=False)
#           (1): BatchNorm2d(88, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(88, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (4): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(96, 96, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=96, bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(96, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (5): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(240, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 240, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (6): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(240, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 240, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (7): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(120, 32, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(32, 120, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(120, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (8): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(48, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(40, 144, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(144, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (9): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=288, bias=False)
#           (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(288, 72, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(72, 288, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(288, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (10): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(576, 144, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(144, 576, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (11): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(576, 144, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(144, 576, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (12): Conv2dNormActivation(
#       (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): Hardswish()
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Linear(in_features=576, out_features=1024, bias=True)
#     (1): Hardswish()
#     (2): Dropout(p=0.2, inplace=True)
#     (3): Linear(in_features=1024, out_features=1280, bias=True)
#     (4): Linear(in_features=1280, out_features=8, bias=True)
#   )
# )

# %%
criterion = nn.CrossEntropyLoss()
#optimizer = optim.Adam(model.classifier.parameters(),lr=0.0001,weight_decay = 0.01)
optimizer = optim.Adam(model.classifier.parameters(), 
                       lr=1e-4, weight_decay=1e-4)

# %%
class EarlyStopper:
    def __init__(self, patience=10, min_delta=0.5):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_accuracy = 0

    def early_stop(self, current_accuracy):
        if (current_accuracy > self.best_accuracy + self.min_delta):
            self.best_accuracy = current_accuracy
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False

# %%
weights_path='MNV3_small_weights_cleaned_noSM.pth'

# %%
early_stopper = EarlyStopper(5, 0.01)
def train_model(model, criterion, optimizer, num_epochs=5):
    training_accuracies = []
    validation_accuracies = []
    training_accuracies.append(0)
    validation_accuracies.append(0)
    #optimizer = optim.Adam(model.fc.parameters(), lr=learning_rate, weight_decay=weight_decay)
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-' * 10)

        for phase in ['train', 'validation']:
            if phase == 'train':
                model.train().to(device) #added to device
            else:
                model.eval().to(device)

            running_loss = 0.0
            running_corrects = 0

            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                outputs = model(inputs).to(device)
                loss = criterion(outputs, labels)

                if phase == 'train':
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()

                _, preds = torch.max(outputs, 1)
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            if phase == 'train':
                epoch_loss = running_loss / len(image_datasets[phase])
                epoch_acc = running_corrects.double() / len(image_datasets[phase])
                training_accuracies.append(epoch_acc.item()*100)
            else:
                epoch_loss = running_loss / len(image_datasets[phase])
                epoch_acc = running_corrects.double() / len(image_datasets[phase])
                validation_accuracies.append(epoch_acc.item()*100)
                if early_stopper.early_stop(epoch_acc.item()*100):
                    print('triggered ES Tacc: {:.4f}, Vacc: {:.4f}'.format(training_accuracies[-1], 
                                                                           validation_accuracies[-1]))            
                    return model,training_accuracies,validation_accuracies
            
                if epoch_acc.item()*100 >= early_stopper.best_accuracy:
                    #early_stopper.early_stop(epoch_acc.item()*100)
                    #early_stopper.best_accuracy = epoch_acc.item()*100
                    print('best accuracy {:.4f}'.format(early_stopper.best_accuracy))
                    torch.save(model.state_dict(), weights_path)
                    print(f"Model saved as it achieved the best validation accuracy so far {early_stopper.best_accuracy}" )

            print('{} loss: {:.4f}, acc: {:.4f}'.format(phase,
                                                        epoch_loss,
                                                        epoch_acc))
    return model,training_accuracies,validation_accuracies

# %%
model_trained = train_model(model, criterion, optimizer, num_epochs=500) #1 epoch for testing gpu
# Out:
# Epoch 1/500
# ----------
# train loss: 1.0399, acc: 0.6273
# best accuracy 76.3423
# Model saved as it achieved the best validation accuracy so far 76.34225328106358
# validation loss: 0.7044, acc: 0.7634
# Epoch 2/500
# ----------
# train loss: 0.6961, acc: 0.7495
# best accuracy 80.7738
# Model saved as it achieved the best validation accuracy so far 80.77381966933697
# validation loss: 0.5751, acc: 0.8077
# Epoch 3/500
# ----------
# train loss: 0.6340, acc: 0.7731
# best accuracy 81.9328
# Model saved as it achieved the best validation accuracy so far 81.93284472473155
# validation loss: 0.5413, acc: 0.8193
# Epoch 4/500
# ----------
# train loss: 0.5877, acc: 0.7898
# validation loss: 0.5240, acc: 0.8152
# Epoch 5/500
# ----------
# train loss: 0.5572, acc: 0.8013
# validation loss: 0.5703, acc: 0.8025
# Epoch 6/500
# ----------
# train loss: 0.5386, acc: 0.8071
# best accuracy 83.0407
# Model saved as it achieved the best validation accuracy so far 83.0407363217999
# validation loss: 0.4845, acc: 0.8304
# Epoch 7/500
# ----------
# train loss: 0.5175, acc: 0.8140
# best accuracy 84.4554
# Model saved as it achieved the best validation accuracy so far 84.45542866882563
# validation loss: 0.4540, acc: 0.8446
# Epoch 8/500
# ----------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 model_trained = train_model(model, criterion, optimizer, num_epochs=500)
#
# Cell In[111], line 21, in train_model(model, criterion, optimizer, num_epochs)
#      18 running_loss = 0.0
#      19 running_corrects = 0
# ---> 21 for inputs, labels in dataloaders[phase]:
#      22     inputs = inputs.to(device)
#      23     labels = labels.to(device)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\torch\utils\data\dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\torch\utils\data\dataloader.py:1329, in _MultiProcessingDataLoaderIter._next_data(self)
#    1326     return self._process_data(data)
#    1328 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1329 idx, data = self._get_data()
#    1330 self._tasks_outstanding -= 1
#    1331 if self._dataset_kind == _DatasetKind.Iterable:
#    1332     # Check for _IterableDatasetStopIteration
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\torch\utils\data\dataloader.py:1295, in _MultiProcessingDataLoaderIter._get_data(self)
#    1291     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1292     # need to call `.task_done()` because we don't use `.join()`.
#    1293 else:
#    1294     while True:
# -> 1295         success, data = self._try_get_data()
#    1296         if success:
#    1297             return data
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\torch\utils\data\dataloader.py:1133, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1120 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1121     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1122     # This can also be used as inner loop of fetching without timeout, with
#    (...)
#    1130     # Returns a 2-tuple:
#    1131     #   (bool: whether successfully get data, any: data if successful else None)
#    1132     try:
# -> 1133         data = self._data_queue.get(timeout=timeout)
#    1134         return (True, data)
#    1135     except Exception as e:
#    1136         # At timeout and error, we manually check whether any worker has
#    1137         # failed. Note that this is the only mechanism for Windows to detect
#    1138         # worker failures.
#
# File ~\AppData\Local\anaconda3\Lib\multiprocessing\queues.py:113, in Queue.get(self, block, timeout)
#     111 if block:
#     112     timeout = deadline - time.monotonic()
# --> 113     if not self._poll(timeout):
#     114         raise Empty
#     115 elif not self._poll():
#
# File ~\AppData\Local\anaconda3\Lib\multiprocessing\connection.py:256, in _ConnectionBase.poll(self, timeout)
#     254 self._check_closed()
#     255 self._check_readable()
# --> 256 return self._poll(timeout)
#
# File ~\AppData\Local\anaconda3\Lib\multiprocessing\connection.py:329, in PipeConnection._poll(self, timeout)
#     326 if (self._got_empty_message or
#     327             _winapi.PeekNamedPipe(self._handle)[0] != 0):
#     328     return True
# --> 329 return bool(wait([self], timeout))
#
# File ~\AppData\Local\anaconda3\Lib\multiprocessing\connection.py:878, in wait(object_list, timeout)
#     875                 ready_objects.add(o)
#     876                 timeout = 0
# --> 878     ready_handles = _exhaustive_wait(waithandle_to_obj.keys(), timeout)
#     879 finally:
#     880     # request that overlapped reads stop
#     881     for ov in ov_list:
#
# File ~\AppData\Local\anaconda3\Lib\multiprocessing\connection.py:810, in _exhaustive_wait(handles, timeout)
#     808 ready = []
#     809 while L:
# --> 810     res = _winapi.WaitForMultipleObjects(L, False, timeout)
#     811     if res == WAIT_TIMEOUT:
#     812         break
#
# KeyboardInterrupt:

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(model, dataloader, num_classes, class_labels):
    # Set the model to evaluation mode
    model.eval()

    # Initialize lists to store the true and predicted labels
    true_labels = []
    pred_labels = []

    # Iterate over the validation dataset
    with torch.no_grad():
        for images, labels in dataloader:

            # Move the input tensor to the same device as the model weights
            if next(model.parameters()).is_cuda:
                images = images.cuda()

            # Forward pass
            outputs = model(images)

            # Get the predicted labels
            _, predicted = torch.max(outputs.data, 1)


            # Store the true and predicted labels
            true_labels += labels.cpu().numpy().tolist()
            pred_labels += predicted.cpu().numpy().tolist()

    #print(true_labels)
    # Compute the confusion matrix
    cm = confusion_matrix(true_labels, pred_labels)
    
    # Plot the confusion matrix
    plt.figure(figsize=(10, 8))
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted label')
    plt.ylabel('True label')
    plt.imshow(cm, cmap='Blues')
    plt.xticks(range(num_classes),classes_labels)
    plt.yticks(range(num_classes),classes_labels)
    cm = np.around(cm.astype('float')/cm.sum(axis=1)[:,np.newaxis],decimals=2)
    plt.colorbar()
    plt.clim(0, max(cm.max(), cm.sum()))
    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
      color = "white" if cm[i, j] > thresh else "black"
      plt.text(j, i, cm[i, j], horizontalalignment="center", color=color)


    plt.tight_layout()
    plt.ylim(num_classes, -0.5)
    plt.imshow(cm, cmap='Blues', vmin=0, vmax=1)

# %%
plot_confusion_matrix(model,dataloaders['validation'],8,eyeGazeClasses)

# %%
import cv2
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
# Preprocess the image (assuming frame is a path or numpy array)
frame = "test/cropped_with_box_350.png"
pil_image = Image.fromarray(cv2.cvtColor(cv2.imread(frame), cv2.COLOR_BGR2RGB))
width, height = pil_image.size
cropped_image = pil_image.crop((0, 0, width, 120))
input_image = transform(cropped_image).unsqueeze(0)  # Add batch dimension

# Make prediction
output = model(input_image)

# Get the predicted class with the highest probability
_, predicted = torch.max(output.data, 1)

# Print the predicted class
print(f"Predicted Class: {eyeGazeClasses[predicted.item()]}")
print(output)
# Out:
# Predicted Class: Rearview
# tensor([[1.1706e-15, 1.0139e-04, 1.4191e-09, 1.3029e-12, 8.6234e-01, 1.3755e-01,
#          9.4882e-06, 6.2106e-09]], grad_fn=<SoftmaxBackward0>)

# %%
# Show the image (assuming it's a color image)
plt.imshow(pil_image)
plt.title(f"Predicted Class: {eyeGazeClasses[predicted.item()]}")
plt.show()

# %%
model_path='MNV3_small_weights_cleaned_100.pth'

model =torchvision.models.mobilenet_v3_small(pretrained=True)

for param in model.parameters():
    param.requires_grad = False

# Define constants
NUM_CLASSES = 8
INPUT_FEATURES = 576
HIDDEN_FEATURES = 1024
OUTPUT_FEATURES = 1280

# Define the custom classifier
classifier = nn.Sequential(
    nn.Linear(INPUT_FEATURES, HIDDEN_FEATURES, bias=True),
    nn.Hardswish(),
    nn.Dropout(p=0.2, inplace=True),
    nn.Linear(HIDDEN_FEATURES, OUTPUT_FEATURES, bias=True),
    nn.Linear(OUTPUT_FEATURES, NUM_CLASSES, bias=True),  # Output layer with 8 classes
    nn.Softmax(dim=1)
)

# Replace the default classifier with the custom one
model.classifier = classifier
model.load_state_dict(torch.load(model_path))
model.eval()
eyeGazeClasses = ['Eyes Closed', 'Forward', 'Left Mirror', 'Radio', 
                  'Rearview', 'Right Mirror', 'Shoulder', 'Speedometer']

# %%
import os
import torchvision.transforms as transforms
import cv2

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])


def preprocess_image(image_path):
    pil_image = Image.fromarray(cv2.cvtColor(cv2.imread(image_path), cv2.COLOR_BGR2RGB))
    width, height = pil_image.size
    cropped_image = pil_image.crop((0, 0, width, 135))
    input_image = transform(cropped_image).unsqueeze(0)  # Add batch dimension
    return input_image

#the test images
test_dir = "Test Data"

# counters for accuracy calculation
total_images = 0
correct_predictions = 0

misclassified_images = []

for class_name in os.listdir(test_dir):
    class_dir = os.path.join(test_dir, class_name)
    if os.path.isdir(class_dir):
        for image_name in os.listdir(class_dir):
            image_path = os.path.join(class_dir, image_name)
            input_image = preprocess_image(image_path)

            #make prediction
            output = model(input_image)
            _, predicted = torch.max(output.data, 1)
            predicted_class = eyeGazeClasses[predicted.item()]

            #if the prediction is correct
            total_images += 1
            if predicted_class == class_name:
                correct_predictions += 1
            else:
                misclassified_images.append((image_name, class_name, predicted_class))

#calculate accuracy
accuracy = correct_predictions / total_images * 100

#results
print(f"Accuracy: {accuracy:.2f}%")
print("Misclassified Images:")
for image_name, true_class, predicted_class in misclassified_images:
    print(f"Image: {image_name}, True Class: {true_class}, Predicted Class: {predicted_class}")
# Out:
# Accuracy: 69.28%
# Misclassified Images:
# Image: cropped2_180.png, True Class: Eyes Closed, Predicted Class: Shoulder
# Image: cropped2_185.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped2_265.png, True Class: Eyes Closed, Predicted Class: Rearview
# Image: cropped2_270.png, True Class: Eyes Closed, Predicted Class: Right Mirror
# Image: cropped2_275.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped2_280.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped2_285.png, True Class: Eyes Closed, Predicted Class: Shoulder
# Image: cropped2_290.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped2_350.png, True Class: Eyes Closed, Predicted Class: Rearview
# Image: cropped2_410.png, True Class: Eyes Closed, Predicted Class: Shoulder
# Image: cropped2_430.png, True Class: Eyes Closed, Predicted Class: Speedometer
png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_100.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_105.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_110.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_1125.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_1130.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_1135.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_1140.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_115.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_1240.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_1245.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_1635.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_1640.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_1840.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_1845.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_2495.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_2500.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_2505.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_2695.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_2700.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_3110.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_3115.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_3170.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_3175.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_3230.png, True Class: Left Mirror, Predicted Class: Eyes Closed
# Image: croppedm_3235.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_605.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_610.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_615.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_620.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_625.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_630.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_635.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_670.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_675.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_680.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_685.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_730.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_735.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_740.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_745.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_800.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_805.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_810.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_815.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_820.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_95.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_960.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_965.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_970.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_975.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_980.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_985.png, True Class: Left Mirror, Predicted Class: Forward
# Image: cropped_470.png, True Class: Left Mirror, Predicted Class: Forward
# Image: cropped_475.png, True Class: Left Mirror, Predicted Class: Forward
# Image: cropped_480.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: cropped_485.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: cropped_490.png, True Class: Left Mirror, Predicted Class: Right Mirror
# Image: cropped_510.png, True Class: Left Mirror, Predicted Class: Right Mirror
# Image: cropped_515.png, True Class: Left Mirror, Predicted Class: Right Mirror
# Image: cropped_520.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: cropped4_505.png, True Class: Radio, Predicted Class: Speedometer
# Image: cropped4_510.png, True Class: Radio, Predicted Class: Speedometer
# Image: cropped4_515.png, True Class: Radio, Predicted Class: Speedometer
# Image: cropped4_520.png, True Class: Radio, Predicted Class: Speedometer
# Image: croppedm_0.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_10.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_15.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_1920.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_1925.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_1930.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_20.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_250.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_255.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_260.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_265.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_270.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_350.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_355.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_360.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_3730.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_3735.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_5.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_890.png, True Class: Radio, Predicted Class: Forward
# Image: cropped4_1185.png, True Class: Rearview, Predicted Class: Speedometer
# Image: cropped4_1190.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_125.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_1280.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_135.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_140.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_2390.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_2395.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_2420.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_2425.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_2515.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_2520.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_2525.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_2815.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_300.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_305.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_320.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_325.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_330.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_3365.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_340.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_3420.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_3425.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_3430.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_345.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_365.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_370.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_3725.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_530.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_535.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_540.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_545.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_550.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_555.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_560.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_565.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_570.png, True Class: Rearview, Predicted Class: Forward
# Image: cropped4_380.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_1500.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_1505.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_1510.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2020.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2025.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2030.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2035.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2040.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2045.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2355.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2360.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2365.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2370.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2545.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2550.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2555.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2560.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2565.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_3320.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_3325.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_3330.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_3745.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_3750.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_3755.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_380.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_385.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_415.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_420.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_425.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_435.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_470.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_475.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_480.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_485.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_490.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_495.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_500.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_580.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_585.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_60.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_65.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_930.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_935.png, True Class: Right Mirror, Predicted Class: Forward
# Image: cropped2_55.png, True Class: Shoulder, Predicted Class: Right Mirror
# Image: croppedm_450.png, True Class: Shoulder, Predicted Class: Rearview
# Image: croppedm_460.png, True Class: Shoulder, Predicted Class: Rearview
# Image: cropped_445.png, True Class: Shoulder, Predicted Class: Eyes Closed
# Image: croppedm_1445.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1450.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1455.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1460.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1465.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1470.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1700.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1705.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1710.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1735.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1740.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1745.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1750.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1755.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_200.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_205.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_210.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_215.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_220.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_225.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_230.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_2460.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_2465.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_2575.png, True Class: Speedometer, Predicted Class: Forward

# %%
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import itertools
import torchvision.transforms as transforms
from torchvision import models
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import cv2
import torch.nn as nn

# Define the image transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Define a custom dataset class
class EyeGazeDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.image_paths = []
        self.labels = []

        for label, class_name in enumerate(eyeGazeClasses):
            class_dir = os.path.join(root_dir, class_name)
            for image_name in os.listdir(class_dir):
                self.image_paths.append(os.path.join(class_dir, image_name))
                self.labels.append(label)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        pil_image = Image.fromarray(cv2.cvtColor(cv2.imread(image_path), cv2.COLOR_BGR2RGB))
        width, height = pil_image.size
        cropped_image = pil_image.crop((0, 0, width, 125))  # Crop the top 130 pixels
        image = self.transform(cropped_image)
        label = self.labels[idx]

        return image, label

model_path="MNV3_small_weights_cleaned_100.pth"

model = models.mobilenet_v3_small(pretrained=True)

for param in model.parameters():
    param.requires_grad = False

# Define constants
NUM_CLASSES = 8
INPUT_FEATURES = 576
HIDDEN_FEATURES = 1024
OUTPUT_FEATURES = 1280

# Define the custom classifier
classifier = nn.Sequential(
    nn.Linear(INPUT_FEATURES, HIDDEN_FEATURES, bias=True),
    nn.Hardswish(),
    nn.Dropout(p=0.2, inplace=True),
    nn.Linear(HIDDEN_FEATURES, OUTPUT_FEATURES, bias=True),
    nn.Linear(OUTPUT_FEATURES, NUM_CLASSES, bias=True),  # Output layer with 8 classes
    nn.Softmax(dim=1)
)

# Replace the default classifier with the custom one
model.classifier = classifier
model.load_state_dict(torch.load(model_path))
model.eval()

eyeGazeClasses = ['Eyes Closed', 'Forward', 'Left Mirror', 'Radio', 
                  'Rearview', 'Right Mirror', 'Shoulder', 'Speedometer']
classes_labels=['Eyes Closed', 'Forward', 'Left Mirror', 'Radio', 
                  'Rearview', 'Right Mirror', 'Shoulder', 'Speedometer']

# Function to preprocess the image
def preprocess_image(image_path):
    pil_image = Image.fromarray(cv2.cvtColor(cv2.imread(image_path), cv2.COLOR_BGR2RGB))
    width, height = pil_image.size
    cropped_image = pil_image.crop((0, 0, width, 125))  # Crop the top 130 pixels
    input_image = transform(cropped_image).unsqueeze(0)  # Add batch dimension
    return input_image, pil_image

# Define the dataloader for the testing data
test_folder_path = "Test Data"
test_dataset = EyeGazeDataset(root_dir=test_folder_path, transform=transform)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False)

def plot_confusion_matrix(model, dataloader, num_classes, class_labels):
    # Set the model to evaluation mode
    model.eval()

    # Initialize lists to store the true and predicted labels
    true_labels = []
    pred_labels = []

    # Iterate over the validation dataset
    with torch.no_grad():
        for images, labels in dataloader:

            # Move the input tensor to the same device as the model weights
            if next(model.parameters()).is_cuda:
                images = images.cuda()

            # Forward pass
            outputs = model(images)

            # Get the predicted labels
            _, predicted = torch.max(outputs.data, 1)


            # Store the true and predicted labels
            true_labels += labels.cpu().numpy().tolist()
            pred_labels += predicted.cpu().numpy().tolist()

    # Compute the confusion matrix
    cm = confusion_matrix(true_labels, pred_labels)
    
    # Plot the confusion matrix
    plt.figure(figsize=(10, 7))
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted label')
    plt.ylabel('True label')
    plt.imshow(cm, cmap='Blues')
    plt.xticks(range(num_classes),class_labels)
    plt.yticks(range(num_classes),class_labels)
    cm = np.around(cm.astype('float')/cm.sum(axis=1)[:,np.newaxis],decimals=2)
    plt.colorbar()
    plt.clim(0, max(cm.max(), cm.sum()))
    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
      color = "white" if cm[i, j] > thresh else "black"
      plt.text(j, i, cm[i, j], horizontalalignment="center", color=color)


    plt.tight_layout()
    plt.ylim(num_classes, -0.5)
    plt.imshow(cm, cmap='Blues', vmin=0, vmax=1)


# Plot the confusion matrix using the test data
plot_confusion_matrix(model, test_dataloader,8,eyeGazeClasses)
# Out:
# C:\Users\AS-GP\AppData\Local\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\AS-GP\AppData\Local\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V3_Small_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V3_Small_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import itertools
import torchvision.transforms as transforms
from torchvision import models
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import cv2
import torch.nn as nn

# Define the image transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Define a custom dataset class
class EyeGazeDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.image_paths = []
        self.labels = []

        for label, class_name in enumerate(eyeGazeClasses):
            class_dir = os.path.join(root_dir, class_name)
            for image_name in os.listdir(class_dir):
                self.image_paths.append(os.path.join(class_dir, image_name))
                self.labels.append(label)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        pil_image = Image.fromarray(cv2.cvtColor(cv2.imread(image_path), cv2.COLOR_BGR2RGB))
        width, height = pil_image.size
        cropped_image = pil_image.crop((0, 0, width, 135))  # Crop the top 130 pixels
        image = self.transform(cropped_image)
        label = self.labels[idx]

        return image, label

model_path="MNV3_small_weights_cleaned_500.pth"

model = models.mobilenet_v3_small(pretrained=True)

for param in model.parameters():
    param.requires_grad = False

# Define constants
NUM_CLASSES = 8
INPUT_FEATURES = 576
HIDDEN_FEATURES = 1024
OUTPUT_FEATURES = 1280

# Define the custom classifier
classifier = nn.Sequential(
    nn.Linear(INPUT_FEATURES, HIDDEN_FEATURES, bias=True),
    nn.Hardswish(),
    nn.Dropout(p=0.2, inplace=True),
    nn.Linear(HIDDEN_FEATURES, OUTPUT_FEATURES, bias=True),
    nn.Linear(OUTPUT_FEATURES, NUM_CLASSES, bias=True),  # Output layer with 8 classes
    nn.Softmax(dim=1)
)

# Replace the default classifier with the custom one
model.classifier = classifier
model.load_state_dict(torch.load(model_path))
model.eval()

eyeGazeClasses = ['Eyes Closed', 'Forward', 'Left Mirror', 'Radio', 
                  'Rearview', 'Right Mirror', 'Shoulder', 'Speedometer']
classes_labels=['Eyes Closed', 'Forward', 'Left Mirror', 'Radio', 
                  'Rearview', 'Right Mirror', 'Shoulder', 'Speedometer']

# Function to preprocess the image
def preprocess_image(image_path):
    pil_image = Image.fromarray(cv2.cvtColor(cv2.imread(image_path), cv2.COLOR_BGR2RGB))
    width, height = pil_image.size
    cropped_image = pil_image.crop((0, 0, width, 135))  # Crop the top 130 pixels
    input_image = transform(cropped_image).unsqueeze(0)  # Add batch dimension
    return input_image, pil_image

# Define the dataloader for the testing data
test_folder_path = "Final Test Data"
test_dataset = EyeGazeDataset(root_dir=test_folder_path, transform=transform)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False)

def plot_confusion_matrix(model, dataloader, num_classes, class_labels):
    # Set the model to evaluation mode
    model.eval()

    # Initialize lists to store the true and predicted labels
    true_labels = []
    pred_labels = []

    # Iterate over the validation dataset
    with torch.no_grad():
        for images, labels in dataloader:

            # Move the input tensor to the same device as the model weights
            if next(model.parameters()).is_cuda:
                images = images.cuda()

            # Forward pass
            outputs = model(images)

            # Get the predicted labels
            _, predicted = torch.max(outputs.data, 1)


            # Store the true and predicted labels
            true_labels += labels.cpu().numpy().tolist()
            pred_labels += predicted.cpu().numpy().tolist()

    # Compute the confusion matrix
    cm = confusion_matrix(true_labels, pred_labels)
    
    # Plot the confusion matrix
    plt.figure(figsize=(10, 8))
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted label')
    plt.ylabel('True label')
    plt.imshow(cm, cmap='Blues')
    plt.xticks(range(num_classes),class_labels)
    plt.yticks(range(num_classes),class_labels)
    cm = np.around(cm.astype('float')/cm.sum(axis=1)[:,np.newaxis],decimals=2)
    plt.colorbar()
    plt.clim(0, max(cm.max(), cm.sum()))
    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
      color = "white" if cm[i, j] > thresh else "black"
      plt.text(j, i, cm[i, j], horizontalalignment="center", color=color)


    plt.tight_layout()
    plt.ylim(num_classes, -0.5)
    plt.imshow(cm, cmap='Blues', vmin=0, vmax=1)


# Plot the confusion matrix using the test data
plot_confusion_matrix(model, test_dataloader,8,eyeGazeClasses)
# Out:
# C:\Users\AS-GP\AppData\Local\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\AS-GP\AppData\Local\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V3_Small_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V3_Small_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
import os
import torchvision.transforms as transforms
import cv2

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])


def preprocess_image(image_path):
    pil_image = Image.fromarray(cv2.cvtColor(cv2.imread(image_path), cv2.COLOR_BGR2RGB))
    width, height = pil_image.size
    cropped_image = pil_image.crop((0, 0, width, 155))
    input_image = transform(cropped_image).unsqueeze(0)  # Add batch dimension
    return input_image

#the test images
test_dir = "Unseen test"

# counters for accuracy calculation
total_images = 0
correct_predictions = 0

accurately_detected_images = []
misclassified_images = []

for class_name in os.listdir(test_dir):
    class_dir = os.path.join(test_dir, class_name)
    if os.path.isdir(class_dir):
        for image_name in os.listdir(class_dir):
            image_path = os.path.join(class_dir, image_name)
            input_image = preprocess_image(image_path)

            #make prediction
            output = model(input_image)
            _, predicted = torch.max(output.data, 1)
            predicted_class = eyeGazeClasses[predicted.item()]

            #if the prediction is correct
            total_images += 1
            if predicted_class == class_name:
                correct_predictions += 1
                accurately_detected_images.append((image_name, class_name, predicted_class))
            else:
                misclassified_images.append((image_name, class_name, predicted_class))

#calculate accuracy
accuracy = correct_predictions / total_images * 100

#results
print(f"Accuracy: {accuracy:.2f}%")
print("Accurately Detected Images:")
for image_name, true_class, predicted_class in accurately_detected_images:
    print(f"Image: {image_name}, True Class: {true_class}, Predicted Class: {predicted_class}")
print("Misclassified Images:")
for image_name, true_class, predicted_class in misclassified_images:
    print(f"Image: {image_name}, True Class: {true_class}, Predicted Class: {predicted_class}")
# Out:
# Accuracy: 30.82%
# Accurately Detected Images:
# Image: croppeda1_210.png, True Class: Eyes Closed, Predicted Class: Eyes Closed
# Image: croppeda1_325.png, True Class: Eyes Closed, Predicted Class: Eyes Closed
# Image: croppeda1_520.png, True Class: Eyes Closed, Predicted Class: Eyes Closed
# Image: croppeda2_1160.png, True Class: Eyes Closed, Predicted Class: Eyes Closed
# Image: croppeda2_1235.png, True Class: Eyes Closed, Predicted Class: Eyes Closed
# Image: croppeda2_1485.png, True Class: Eyes Closed, Predicted Class: Eyes Closed
# Image: croppeda2_1560.png, True Class: Eyes Closed, Predicted Class: Eyes Closed
# Image: croppeda2_1670.png, True Class: Eyes Closed, Predicted Class: Eyes Closed
# Image: croppeda2_2300.png, True Class: Eyes Closed, Predicted Class: Eyes Closed
# Image: croppedg1_115.png, True Class: Eyes Closed, Predicted Class: Eyes Closed
# Image: croppedg1_140.png, True Class: Eyes Closed, Predicted Class: Eyes Closed
# Image: croppedg1_200.png, True Class: Eyes Closed, Predicted Class: Eyes Closed
# Image: croppedg1_395.png, True Class: Eyes Closed, Predicted Class: Eyes Closed
# Image: croppeda2_1555.png, True Class: Radio, Predicted Class: Shoulder
# Image: croppeda2_1565.png, True Class: Radio, Predicted Class: Right Mirror
# Image: croppeda2_1570.png, True Class: Radio, Predicted Class: Right Mirror
# Image: croppeda2_1575.png, True Class: Radio, Predicted Class: Right Mirror
# Image: croppeda2_2030.png, True Class: Radio, Predicted Class: Forward
# Image: croppeda2_2035.png, True Class: Radio, Predicted Class: Right Mirror
# Image: croppeda2_2040.png, True Class: Radio, Predicted Class: Right Mirror
# Image: croppeda2_2045.png, True Class: Radio, Predicted Class: Right Mirror
# Image: croppeda2_2050.png, True Class: Radio, Predicted Class: Right Mirror
# Image: croppeda2_2055.png, True Class: Radio, Predicted Class: Right Mirror
# Image: croppeda2_2060.png, True Class: Radio, Predicted Class: Right Mirror
# Image: croppeda2_2065.png, True Class: Radio, Predicted Class: Right Mirror
# Image: croppedg1_315.png, True Class: Radio, Predicted Class: Eyes Closed
# Image: croppedg1_320.png, True Class: Radio, Predicted Class: Eyes Closed
# Image: croppedg1_325.png, True Class: Radio, Predicted Class: Eyes Closed
# Image: croppedg1_330.png, True Class: Radio, Predicted Class: Eyes Closed
# Image: croppedg1_335.png, True Class: Radio, Predicted Class: Speedometer
# Image: croppedg1_340.png, True Class: Radio, Predicted Class: Speedometer
# Image: croppedg1_345.png, True Class: Radio, Predicted Class: Eyes Closed
# Image: croppedg1_350.png, True Class: Radio, Predicted Class: Eyes Closed
# Image: croppedg1_355.png, True Class: Radio, Predicted Class: Forward
# Image: croppedg1_360.png, True Class: Radio, Predicted Class: Eyes Closed
# Image: croppedg1_365.png, True Class: Radio, Predicted Class: Eyes Closed
# Image: croppedg1_370.png, True Class: Radio, Predicted Class: Speedometer
# Image: croppedg1_375.png, True Class: Radio, Predicted Class: Forward
# Image: croppedg1_380.png, True Class: Radio, Predicted Class: Speedometer
# Image: croppedm1_770.png, True Class: Radio, Predicted Class: Speedometer
# Image: croppeda1_215.png, True Class: Rearview, Predicted Class: Forward
# Image: croppeda1_220.png, True Class: Rearview, Predicted Class: Forward
# Image: croppeda1_225.png, True Class: Rearview, Predicted Class: Forward
# Image: croppeda1_230.png, True Class: Rearview, Predicted Class: Forward
# Image: croppeda1_235.png, True Class: Rearview, Predicted Class: Forward
# Image: croppeda1_240.png, True Class: Rearview, Predicted Class: Forward
# Image: croppeda1_245.png, True Class: Rearview, Predicted Class: Forward
# Image: croppeda1_250.png, True Class: Rearview, Predicted Class: Forward
# Image: croppeda1_255.png, True Class: Rearview, Predicted Class: Forward
# Image: croppeda1_260.png, True Class: Rearview, Predicted Class: Forward
# Image: croppeda1_265.png, True Class: Rearview, Predicted Class: Forward
# Image: croppeda1_270.png, True Class: Rearview, Predicted Class: Forward
# Image: croppeda1_275.png, True Class: Rearview, Predicted Class: Forward
# Image: croppeda1_280.png, True Class: Rearview, Predicted Class: Forward
# Image: croppeda1_285.png, True Class: Rearview, Predicted Class: Forward
# Image: croppeda1_290.png, True Class: Rearview, Predicted Class: Forward
# Image: croppeda1_295.png, True Class: Rearview, Predicted Class: Forward
png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedy2_265.png, True Class: Speedometer, Predicted Class: Rearview
# Image: croppedy2_270.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedy2_275.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedy3_335.png, True Class: Speedometer, Predicted Class: Shoulder
# Image: croppedy3_340.png, True Class: Speedometer, Predicted Class: Shoulder
# Image: croppedy3_345.png, True Class: Speedometer, Predicted Class: Shoulder
# Image: croppedy3_350.png, True Class: Speedometer, Predicted Class: Shoulder
# Image: croppedy3_355.png, True Class: Speedometer, Predicted Class: Shoulder
# Image: croppedy3_360.png, True Class: Speedometer, Predicted Class: Shoulder
# Image: croppedy3_365.png, True Class: Speedometer, Predicted Class: Shoulder
# Image: croppedy3_370.png, True Class: Speedometer, Predicted Class: Eyes Closed
# Image: croppedy3_420.png, True Class: Speedometer, Predicted Class: Shoulder
# Image: croppedy3_440.png, True Class: Speedometer, Predicted Class: Right Mirror
# Image: croppedy3_455.png, True Class: Speedometer, Predicted Class: Shoulder
# Image: croppedy3_460.png, True Class: Speedometer, Predicted Class: Shoulder
# Image: croppedy3_465.png, True Class: Speedometer, Predicted Class: Shoulder

# %%
Image: croppeda1_300.png, True Class: Rearview, Predicted Class: Rearview
Image: croppeda2_1870.png, True Class: Rearview, Predicted Class: Rearview
Image: croppeda2_1875.png, True Class: Rearview, Predicted Class: Rearview
Image: croppeda2_1890.png, True Class: Rearview, Predicted Class: Rearview
Image: croppeda2_1905.png, True Class: Rearview, Predicted Class: Rearview
Image: croppeda2_1930.png, True Class: Rearview, Predicted Class: Rearview
Image: croppedm1_105.png, True Class: Rearview, Predicted Class: Rearview
Image: croppedm1_110.png, True Class: Rearview, Predicted Class: Rearview
Image: croppedm1_120.png, True Class: Rearview, Predicted Class: Rearview
Image: croppedm1_130.png, True Class: Rearview, Predicted Class: Rearview
Image: croppedm1_75.png, True Class: Rearview, Predicted Class: Rearview
Image: croppedm1_80.png, True Class: Rearview, Predicted Class: Rearview
Image: croppedm1_95.png, True Class: Rearview, Predicted Class: Rearview
Image: croppedy1_210.png, True Class: Rearview, Predicted Class: Rearview

# %%
import cv2
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
# Preprocess the image (assuming frame is a path or numpy array)
frame = "Unseen test/Eyes Closed/croppedg1_465.png"
pil_image = Image.fromarray(cv2.cvtColor(cv2.imread(frame), cv2.COLOR_BGR2RGB))
width, height = pil_image.size
cropped_image = pil_image.crop((0, 0, width, 120))
input_image = transform(cropped_image).unsqueeze(0)  # Add batch dimension

# Make prediction
output = model(input_image)

# Get the predicted class with the highest probability
_, predicted = torch.max(output.data, 1)

# Print the predicted class
print(f"Predicted Class: {eyeGazeClasses[predicted.item()]}")
print(output)
# Show the image (assuming it's a color image)
plt.imshow(pil_image)
plt.title(f"Predicted Class: {eyeGazeClasses[predicted.item()]}")
plt.show()
# Out:
# Predicted Class: Eyes Closed
# tensor([[9.9980e-01, 8.0934e-08, 5.0681e-11, 5.9312e-08, 1.4131e-04, 2.1004e-05,
#          5.8064e-06, 3.4832e-05]], grad_fn=<SoftmaxBackward0>)
