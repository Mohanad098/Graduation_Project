# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image
import torch
from torchvision import datasets, models, transforms
import torch.nn as nn
from torch.nn import functional as F
import torch.optim as optim
import torchvision

# %%
original_folder = "C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/lisat_gaze_data_mixed/train"

# %% [markdown]
# # Splitting Training & Validation Dataset

# %%
import os
train_folder ="C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/train"
def count_files_in_folders(directory):
  for root, dirs, files in os.walk(directory):
    print(f"Folder: {root}")
    file_count = len(files)
    print(f"Number of files: {file_count}")
    print("-" * 20)
count_files_in_folders(train_folder)
# Out:
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/train
# Number of files: 0
# --------------------
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/train\Eyes Closed
# Number of files: 1737
# --------------------
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/train\Forward
# Number of files: 2824
# --------------------
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/train\Left Mirror
# Number of files: 2600
# --------------------
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/train\Radio
# Number of files: 2820
# --------------------
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/train\Rearview
# Number of files: 2694
# --------------------
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/train\Right Mirror
# Number of files: 2512
# --------------------
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/train\Shoulder
# Number of files: 4658
# --------------------
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/train\Speedometer
# Number of files: 2711
# --------------------

# %%
val_folder ="C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/val"
def count_files_in_folders(directory):
  for root, dirs, files in os.walk(directory):
    print(f"Folder: {root}")
    file_count = len(files)
    print(f"Number of files: {file_count}")
    print("-" * 20)
count_files_in_folders(val_folder)
# Out:
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/val
# Number of files: 0
# --------------------
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/val\Eyes Closed
# Number of files: 501
# --------------------
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/val\Forward
# Number of files: 705
# --------------------
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/val\Left Mirror
# Number of files: 646
# --------------------
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/val\Radio
# Number of files: 685
# --------------------
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/val\Rearview
# Number of files: 687
# --------------------
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/val\Right Mirror
# Number of files: 628
# --------------------
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/val\Shoulder
# Number of files: 1256
# --------------------
# Folder: C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/split_new/val\Speedometer
# Number of files: 759
# --------------------

# %%
input_path='C:/Users/AS-GP/Desktop/Resnet50/lisat_gaze_data_v1/'

# %%
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])

data_transforms = {
    'train':
    transforms.Compose([
        transforms.Resize((224,224)),
        transforms.RandomAffine(0, shear=10, scale=(0.8,1.2)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        normalize
    ]),
    'validation':
    transforms.Compose([
        transforms.Resize((224,224)),
        transforms.ToTensor(), #for parallel computations
        normalize
    ]),
}

#train_subset_size = int(0.4 * len(datasets.ImageFolder(input_path + 'train_1250', transform=data_transforms['train']))) #testing hashelha b3den

image_datasets = {
    'train':
    datasets.ImageFolder(input_path + 'split_new/train', data_transforms['train']),
    'validation':
    datasets.ImageFolder(input_path + 'split_new/val', data_transforms['validation'])
}

dataloaders = {
    'train':
    torch.utils.data.DataLoader(image_datasets['train'],
                                batch_size=32,
                                shuffle=True,
                                num_workers=2),  # for now 2
    'validation':
    torch.utils.data.DataLoader(image_datasets['validation'],
                                batch_size=32,
                                shuffle=False,
                                num_workers=2)  # for Kaggle
}

# %%
print("Train dataset size:", len(image_datasets['train']))
print("Validation dataset size:", len(image_datasets['validation']))
# Out:
# Train dataset size: 22556
# Validation dataset size: 5867

# %%
# from torch.utils.data import random_split

# normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
#                                  std=[0.229, 0.224, 0.225])

# data_transforms = {
#     'train':
#     transforms.Compose([
#         transforms.Resize((224,224)),
#         transforms.RandomAffine(0, shear=10, scale=(0.8,1.2)),
#         transforms.RandomHorizontalFlip(),
#         transforms.ToTensor(),
#         normalize
#     ])
# }
# full_dataset = datasets.ImageFolder(input_path + 
#                                     '/train', 
#                                     data_transforms['train'])

# # Calculate the sizes of the training and validation sets
# train_size = int(0.8 * len(full_dataset))
# val_size = len(full_dataset) - train_size

# # Split the dataset into training and validation sets
# train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

# # Create data loaders for training and validation sets
# dataloaders = {
#     'train': torch.utils.data.DataLoader(train_dataset,
#                                          batch_size=32,
#                                          shuffle=True,
#                                          num_workers=2),
#     'validation': torch.utils.data.DataLoader(val_dataset,
#                                               batch_size=32,
#                                               shuffle=True,
#                                               num_workers=2)
# }
# print(len(train_dataset))
# print(len(val_dataset))

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
model =torchvision.models.mobilenet_v3_small(pretrained=True).to(device)
model
# Out:
# C:\Users\AS-GP\AppData\Local\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\AS-GP\AppData\Local\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V3_Small_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V3_Small_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# MobileNetV3(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): Hardswish()
#     )
#     (1): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=16, bias=False)
#           (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(16, 8, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(8, 16, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (2): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(72, 72, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=72, bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (3): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(88, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(88, 88, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=88, bias=False)
#           (1): BatchNorm2d(88, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(88, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (4): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(96, 96, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=96, bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(96, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (5): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(240, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 240, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (6): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(240, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 240, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (7): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(120, 32, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(32, 120, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(120, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (8): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(48, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(40, 144, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(144, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (9): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=288, bias=False)
#           (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(288, 72, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(72, 288, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(288, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (10): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(576, 144, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(144, 576, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (11): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(576, 144, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(144, 576, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (12): Conv2dNormActivation(
#       (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): Hardswish()
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Linear(in_features=576, out_features=1024, bias=True)
#     (1): Hardswish()
#     (2): Dropout(p=0.2, inplace=True)
#     (3): Linear(in_features=1024, out_features=1000, bias=True)
#   )
# )

# %%
model =torchvision.models.mobilenet_v3_small(pretrained=True).to(device)

for param in model.parameters():
    param.requires_grad = False

# Define constants
NUM_CLASSES = 8
INPUT_FEATURES = 576
HIDDEN_FEATURES = 1024
OUTPUT_FEATURES = 1280

# Define the custom classifier
classifier = nn.Sequential(
    nn.Linear(INPUT_FEATURES, HIDDEN_FEATURES, bias=True),
    nn.Hardswish(),
    nn.Dropout(p=0.2, inplace=True),
    nn.Linear(HIDDEN_FEATURES, OUTPUT_FEATURES, bias=True),
    nn.Linear(OUTPUT_FEATURES, NUM_CLASSES, bias=True),  # Output layer with 8 classes
    #nn.Softmax(dim=1)
)

# Replace the default classifier with the custom one
model.classifier = classifier

model
# Out:
# C:\Users\AS-GP\AppData\Local\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\AS-GP\AppData\Local\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V3_Small_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V3_Small_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# MobileNetV3(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): Hardswish()
#     )
#     (1): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=16, bias=False)
#           (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(16, 8, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(8, 16, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (2): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(72, 72, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=72, bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (3): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(88, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(88, 88, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=88, bias=False)
#           (1): BatchNorm2d(88, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(88, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (4): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(96, 96, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=96, bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(96, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (5): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(240, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 240, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (6): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(240, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 240, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (7): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(120, 32, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(32, 120, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(120, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (8): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(48, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(40, 144, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(144, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (9): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=288, bias=False)
#           (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(288, 72, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(72, 288, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(288, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (10): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(576, 144, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(144, 576, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (11): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(576, 144, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(144, 576, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (12): Conv2dNormActivation(
#       (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): Hardswish()
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Linear(in_features=576, out_features=1024, bias=True)
#     (1): Hardswish()
#     (2): Dropout(p=0.2, inplace=True)
#     (3): Linear(in_features=1024, out_features=1280, bias=True)
#     (4): Linear(in_features=1280, out_features=8, bias=True)
#   )
# )

# %%
criterion = nn.CrossEntropyLoss()
#optimizer = optim.Adam(model.classifier.parameters(),lr=0.0001,weight_decay = 0.01)
optimizer = optim.Adam(model.classifier.parameters(), 
                       lr=1e-4, weight_decay=1e-4)

# %%
class EarlyStopper:
    def __init__(self, patience=10, min_delta=0.5):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_accuracy = 0

    def early_stop(self, current_accuracy):
        if (current_accuracy > self.best_accuracy + self.min_delta):
            self.best_accuracy = current_accuracy
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False

# %%
weights_path='MNV3_small_weights_cleaned_noSM.pth'

# %%
early_stopper = EarlyStopper(5, 0.01)
def train_model(model, criterion, optimizer, num_epochs=5):
    training_accuracies = []
    validation_accuracies = []
    training_accuracies.append(0)
    validation_accuracies.append(0)
    #optimizer = optim.Adam(model.fc.parameters(), lr=learning_rate, weight_decay=weight_decay)
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-' * 10)

        for phase in ['train', 'validation']:
            if phase == 'train':
                model.train().to(device) #added to device
            else:
                model.eval().to(device)

            running_loss = 0.0
            running_corrects = 0

            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                outputs = model(inputs).to(device)
                loss = criterion(outputs, labels)

                if phase == 'train':
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()

                _, preds = torch.max(outputs, 1)
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            if phase == 'train':
                epoch_loss = running_loss / len(image_datasets[phase])
                epoch_acc = running_corrects.double() / len(image_datasets[phase])
                training_accuracies.append(epoch_acc.item()*100)
            else:
                epoch_loss = running_loss / len(image_datasets[phase])
                epoch_acc = running_corrects.double() / len(image_datasets[phase])
                validation_accuracies.append(epoch_acc.item()*100)
                if early_stopper.early_stop(epoch_acc.item()*100):
                    print('triggered ES Tacc: {:.4f}, Vacc: {:.4f}'.format(training_accuracies[-1], 
                                                                           validation_accuracies[-1]))            
                    return model,training_accuracies,validation_accuracies
            
                if epoch_acc.item()*100 >= early_stopper.best_accuracy:
                    #early_stopper.early_stop(epoch_acc.item()*100)
                    #early_stopper.best_accuracy = epoch_acc.item()*100
                    print('best accuracy {:.4f}'.format(early_stopper.best_accuracy))
                    torch.save(model.state_dict(), weights_path)
                    print(f"Model saved as it achieved the best validation accuracy so far {early_stopper.best_accuracy}" )

            print('{} loss: {:.4f}, acc: {:.4f}'.format(phase,
                                                        epoch_loss,
                                                        epoch_acc))
    return model,training_accuracies,validation_accuracies

# %%
model_trained = train_model(model, criterion, optimizer, num_epochs=500) #1 epoch for testing gpu
# Out:
# Epoch 1/500
# ----------
# train loss: 1.0399, acc: 0.6273
# best accuracy 76.3423
# Model saved as it achieved the best validation accuracy so far 76.34225328106358
# validation loss: 0.7044, acc: 0.7634
# Epoch 2/500
# ----------
# train loss: 0.6961, acc: 0.7495
# best accuracy 80.7738
# Model saved as it achieved the best validation accuracy so far 80.77381966933697
# validation loss: 0.5751, acc: 0.8077
# Epoch 3/500
# ----------
# train loss: 0.6340, acc: 0.7731
# best accuracy 81.9328
# Model saved as it achieved the best validation accuracy so far 81.93284472473155
# validation loss: 0.5413, acc: 0.8193
# Epoch 4/500
# ----------
# train loss: 0.5877, acc: 0.7898
# validation loss: 0.5240, acc: 0.8152
# Epoch 5/500
# ----------
# train loss: 0.5572, acc: 0.8013
# validation loss: 0.5703, acc: 0.8025
# Epoch 6/500
# ----------
# train loss: 0.5386, acc: 0.8071
# best accuracy 83.0407
# Model saved as it achieved the best validation accuracy so far 83.0407363217999
# validation loss: 0.4845, acc: 0.8304
# Epoch 7/500
# ----------
# train loss: 0.5175, acc: 0.8140
# best accuracy 84.4554
# Model saved as it achieved the best validation accuracy so far 84.45542866882563
# validation loss: 0.4540, acc: 0.8446
# Epoch 8/500
# ----------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 model_trained = train_model(model, criterion, optimizer, num_epochs=500)
#
# Cell In[111], line 21, in train_model(model, criterion, optimizer, num_epochs)
#      18 running_loss = 0.0
#      19 running_corrects = 0
# ---> 21 for inputs, labels in dataloaders[phase]:
#      22     inputs = inputs.to(device)
#      23     labels = labels.to(device)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\torch\utils\data\dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\torch\utils\data\dataloader.py:1329, in _MultiProcessingDataLoaderIter._next_data(self)
#    1326     return self._process_data(data)
#    1328 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1329 idx, data = self._get_data()
#    1330 self._tasks_outstanding -= 1
#    1331 if self._dataset_kind == _DatasetKind.Iterable:
#    1332     # Check for _IterableDatasetStopIteration
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\torch\utils\data\dataloader.py:1295, in _MultiProcessingDataLoaderIter._get_data(self)
#    1291     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1292     # need to call `.task_done()` because we don't use `.join()`.
#    1293 else:
#    1294     while True:
# -> 1295         success, data = self._try_get_data()
#    1296         if success:
#    1297             return data
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\torch\utils\data\dataloader.py:1133, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1120 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1121     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1122     # This can also be used as inner loop of fetching without timeout, with
#    (...)
#    1130     # Returns a 2-tuple:
#    1131     #   (bool: whether successfully get data, any: data if successful else None)
#    1132     try:
# -> 1133         data = self._data_queue.get(timeout=timeout)
#    1134         return (True, data)
#    1135     except Exception as e:
#    1136         # At timeout and error, we manually check whether any worker has
#    1137         # failed. Note that this is the only mechanism for Windows to detect
#    1138         # worker failures.
#
# File ~\AppData\Local\anaconda3\Lib\multiprocessing\queues.py:113, in Queue.get(self, block, timeout)
#     111 if block:
#     112     timeout = deadline - time.monotonic()
# --> 113     if not self._poll(timeout):
#     114         raise Empty
#     115 elif not self._poll():
#
# File ~\AppData\Local\anaconda3\Lib\multiprocessing\connection.py:256, in _ConnectionBase.poll(self, timeout)
#     254 self._check_closed()
#     255 self._check_readable()
# --> 256 return self._poll(timeout)
#
# File ~\AppData\Local\anaconda3\Lib\multiprocessing\connection.py:329, in PipeConnection._poll(self, timeout)
#     326 if (self._got_empty_message or
#     327             _winapi.PeekNamedPipe(self._handle)[0] != 0):
#     328     return True
# --> 329 return bool(wait([self], timeout))
#
# File ~\AppData\Local\anaconda3\Lib\multiprocessing\connection.py:878, in wait(object_list, timeout)
#     875                 ready_objects.add(o)
#     876                 timeout = 0
# --> 878     ready_handles = _exhaustive_wait(waithandle_to_obj.keys(), timeout)
#     879 finally:
#     880     # request that overlapped reads stop
#     881     for ov in ov_list:
#
# File ~\AppData\Local\anaconda3\Lib\multiprocessing\connection.py:810, in _exhaustive_wait(handles, timeout)
#     808 ready = []
#     809 while L:
# --> 810     res = _winapi.WaitForMultipleObjects(L, False, timeout)
#     811     if res == WAIT_TIMEOUT:
#     812         break
#
# KeyboardInterrupt:

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(model, dataloader, num_classes, class_labels):
    # Set the model to evaluation mode
    model.eval()

    # Initialize lists to store the true and predicted labels
    true_labels = []
    pred_labels = []

    # Iterate over the validation dataset
    with torch.no_grad():
        for images, labels in dataloader:

            # Move the input tensor to the same device as the model weights
            if next(model.parameters()).is_cuda:
                images = images.cuda()

            # Forward pass
            outputs = model(images)

            # Get the predicted labels
            _, predicted = torch.max(outputs.data, 1)


            # Store the true and predicted labels
            true_labels += labels.cpu().numpy().tolist()
            pred_labels += predicted.cpu().numpy().tolist()

    #print(true_labels)
    # Compute the confusion matrix
    cm = confusion_matrix(true_labels, pred_labels)
    
    # Plot the confusion matrix
    plt.figure(figsize=(10, 8))
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted label')
    plt.ylabel('True label')
    plt.imshow(cm, cmap='Blues')
    plt.xticks(range(num_classes),classes_labels)
    plt.yticks(range(num_classes),classes_labels)
    cm = np.around(cm.astype('float')/cm.sum(axis=1)[:,np.newaxis],decimals=2)
    plt.colorbar()
    plt.clim(0, max(cm.max(), cm.sum()))
    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
      color = "white" if cm[i, j] > thresh else "black"
      plt.text(j, i, cm[i, j], horizontalalignment="center", color=color)


    plt.tight_layout()
    plt.ylim(num_classes, -0.5)
    plt.imshow(cm, cmap='Blues', vmin=0, vmax=1)

# %%
plot_confusion_matrix(model,dataloaders['validation'],8,eyeGazeClasses)

# %%
import cv2
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
# Preprocess the image (assuming frame is a path or numpy array)
frame = "test/cropped_with_box_350.png"
pil_image = Image.fromarray(cv2.cvtColor(cv2.imread(frame), cv2.COLOR_BGR2RGB))
width, height = pil_image.size
cropped_image = pil_image.crop((0, 0, width, 120))
input_image = transform(cropped_image).unsqueeze(0)  # Add batch dimension

# Make prediction
output = model(input_image)

# Get the predicted class with the highest probability
_, predicted = torch.max(output.data, 1)

# Print the predicted class
print(f"Predicted Class: {eyeGazeClasses[predicted.item()]}")
print(output)
# Out:
# Predicted Class: Rearview
# tensor([[1.1706e-15, 1.0139e-04, 1.4191e-09, 1.3029e-12, 8.6234e-01, 1.3755e-01,
#          9.4882e-06, 6.2106e-09]], grad_fn=<SoftmaxBackward0>)

# %%
# Show the image (assuming it's a color image)
plt.imshow(pil_image)
plt.title(f"Predicted Class: {eyeGazeClasses[predicted.item()]}")
plt.show()

# %%
model_path='MNV3_small_weights_cleaned_100.pth'

model =torchvision.models.mobilenet_v3_small(pretrained=True)

for param in model.parameters():
    param.requires_grad = False

# Define constants
NUM_CLASSES = 8
INPUT_FEATURES = 576
HIDDEN_FEATURES = 1024
OUTPUT_FEATURES = 1280

# Define the custom classifier
classifier = nn.Sequential(
    nn.Linear(INPUT_FEATURES, HIDDEN_FEATURES, bias=True),
    nn.Hardswish(),
    nn.Dropout(p=0.2, inplace=True),
    nn.Linear(HIDDEN_FEATURES, OUTPUT_FEATURES, bias=True),
    nn.Linear(OUTPUT_FEATURES, NUM_CLASSES, bias=True),  # Output layer with 8 classes
    nn.Softmax(dim=1)
)

# Replace the default classifier with the custom one
model.classifier = classifier
model.load_state_dict(torch.load(model_path))
model.eval()
eyeGazeClasses = ['Eyes Closed', 'Forward', 'Left Mirror', 'Radio', 
                  'Rearview', 'Right Mirror', 'Shoulder', 'Speedometer']

# %%
import os
import torchvision.transforms as transforms
import cv2

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])


def preprocess_image(image_path):
    pil_image = Image.fromarray(cv2.cvtColor(cv2.imread(image_path), cv2.COLOR_BGR2RGB))
    width, height = pil_image.size
    cropped_image = pil_image.crop((0, 0, width, 135))
    input_image = transform(cropped_image).unsqueeze(0)  # Add batch dimension
    return input_image

#the test images
test_dir = "Test Data"

# counters for accuracy calculation
total_images = 0
correct_predictions = 0

misclassified_images = []

for class_name in os.listdir(test_dir):
    class_dir = os.path.join(test_dir, class_name)
    if os.path.isdir(class_dir):
        for image_name in os.listdir(class_dir):
            image_path = os.path.join(class_dir, image_name)
            input_image = preprocess_image(image_path)

            #make prediction
            output = model(input_image)
            _, predicted = torch.max(output.data, 1)
            predicted_class = eyeGazeClasses[predicted.item()]

            #if the prediction is correct
            total_images += 1
            if predicted_class == class_name:
                correct_predictions += 1
            else:
                misclassified_images.append((image_name, class_name, predicted_class))

#calculate accuracy
accuracy = correct_predictions / total_images * 100

#results
print(f"Accuracy: {accuracy:.2f}%")
print("Misclassified Images:")
for image_name, true_class, predicted_class in misclassified_images:
    print(f"Image: {image_name}, True Class: {true_class}, Predicted Class: {predicted_class}")
# Out:
# Accuracy: 69.28%
# Misclassified Images:
# Image: cropped2_180.png, True Class: Eyes Closed, Predicted Class: Shoulder
# Image: cropped2_185.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped2_265.png, True Class: Eyes Closed, Predicted Class: Rearview
# Image: cropped2_270.png, True Class: Eyes Closed, Predicted Class: Right Mirror
# Image: cropped2_275.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped2_280.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped2_285.png, True Class: Eyes Closed, Predicted Class: Shoulder
# Image: cropped2_290.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped2_350.png, True Class: Eyes Closed, Predicted Class: Rearview
# Image: cropped2_410.png, True Class: Eyes Closed, Predicted Class: Shoulder
# Image: cropped2_430.png, True Class: Eyes Closed, Predicted Class: Speedometer
# Image: cropped2_435.png, True Class: Eyes Closed, Predicted Class: Right Mirror
# Image: cropped2_440.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped2_445.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped3_100.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped3_105.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped3_110.png, True Class: Eyes Closed, Predicted Class: Rearview
# Image: cropped3_115.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped3_120.png, True Class: Eyes Closed, Predicted Class: Speedometer
# Image: cropped3_125.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped3_130.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped3_135.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped3_45.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped3_50.png, True Class: Eyes Closed, Predicted Class: Shoulder
# Image: cropped3_70.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped3_80.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped3_85.png, True Class: Eyes Closed, Predicted Class: Shoulder
# Image: cropped3_90.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped3_95.png, True Class: Eyes Closed, Predicted Class: Shoulder
# Image: cropped4_1000.png, True Class: Eyes Closed, Predicted Class: Right Mirror
# Image: cropped4_670.png, True Class: Eyes Closed, Predicted Class: Right Mirror
# Image: cropped4_720.png, True Class: Eyes Closed, Predicted Class: Rearview
# Image: cropped4_840.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped4_930.png, True Class: Eyes Closed, Predicted Class: Speedometer
# Image: cropped4_970.png, True Class: Eyes Closed, Predicted Class: Shoulder
# Image: cropped4_975.png, True Class: Eyes Closed, Predicted Class: Right Mirror
# Image: croppedm_1685.png, True Class: Eyes Closed, Predicted Class: Speedometer
# Image: croppedm_1835.png, True Class: Eyes Closed, Predicted Class: Speedometer
# Image: croppedm_1935.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: croppedm_2015.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: croppedm_2050.png, True Class: Eyes Closed, Predicted Class: Speedometer
# Image: croppedm_2230.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: croppedm_2570.png, True Class: Eyes Closed, Predicted Class: Speedometer
# Image: croppedm_590.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: croppedm_70.png, True Class: Eyes Closed, Predicted Class: Speedometer
# Image: cropped_110.png, True Class: Eyes Closed, Predicted Class: Shoulder
# Image: cropped_40.png, True Class: Eyes Closed, Predicted Class: Right Mirror
# Image: cropped_635.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped_640.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped_675.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped_685.png, True Class: Eyes Closed, Predicted Class: Speedometer
# Image: cropped_690.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped_695.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped_705.png, True Class: Eyes Closed, Predicted Class: Shoulder
# Image: cropped_710.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped_715.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped_720.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped2_0.png, True Class: Forward, Predicted Class: Speedometer
# Image: cropped2_100.png, True Class: Forward, Predicted Class: Right Mirror
# Image: cropped2_105.png, True Class: Forward, Predicted Class: Speedometer
# Image: cropped2_110.png, True Class: Forward, Predicted Class: Right Mirror
# Image: cropped2_125.png, True Class: Forward, Predicted Class: Speedometer
# Image: cropped2_160.png, True Class: Forward, Predicted Class: Right Mirror
# Image: cropped2_65.png, True Class: Forward, Predicted Class: Rearview
# Image: cropped2_80.png, True Class: Forward, Predicted Class: Speedometer
# Image: cropped3_25.png, True Class: Forward, Predicted Class: Speedometer
# Image: cropped3_35.png, True Class: Forward, Predicted Class: Right Mirror
# Image: cropped3_40.png, True Class: Forward, Predicted Class: Shoulder
# Image: cropped4_1175(1).png, True Class: Forward, Predicted Class: Rearview
# Image: cropped4_1175.png, True Class: Forward, Predicted Class: Rearview
# Image: cropped4_155(1).png, True Class: Forward, Predicted Class: Left Mirror
# Image: cropped4_155.png, True Class: Forward, Predicted Class: Left Mirror
# Image: cropped4_350(1).png, True Class: Forward, Predicted Class: Right Mirror
# Image: cropped4_350.png, True Class: Forward, Predicted Class: Right Mirror
# Image: cropped4_605.png, True Class: Forward, Predicted Class: Rearview
# Image: cropped4_680.png, True Class: Forward, Predicted Class: Right Mirror
# Image: cropped4_765.png, True Class: Forward, Predicted Class: Shoulder
# Image: cropped4_790.png, True Class: Forward, Predicted Class: Right Mirror
# Image: cropped4_80.png, True Class: Forward, Predicted Class: Rearview
# Image: cropped4_815.png, True Class: Forward, Predicted Class: Speedometer
# Image: croppedm_1340.png, True Class: Forward, Predicted Class: Speedometer
# Image: croppedm_3145.png, True Class: Forward, Predicted Class: Speedometer
# Image: croppedm_3265.png, True Class: Forward, Predicted Class: Speedometer
# Image: cropped_245.png, True Class: Forward, Predicted Class: Right Mirror
# Image: cropped_250.png, True Class: Forward, Predicted Class: Right Mirror
# Image: cropped_255.png, True Class: Forward, Predicted Class: Left Mirror
# Image: cropped_310.png, True Class: Forward, Predicted Class: Shoulder
# Image: cropped_315.png, True Class: Forward, Predicted Class: Right Mirror
# Image: cropped_320.png, True Class: Forward, Predicted Class: Right Mirror
# Image: cropped_340.png, True Class: Forward, Predicted Class: Shoulder
# Image: cropped_365.png, True Class: Forward, Predicted Class: Shoulder
# Image: cropped_370.png, True Class: Forward, Predicted Class: Right Mirror
# Image: cropped_375.png, True Class: Forward, Predicted Class: Right Mirror
# Image: cropped_410.png, True Class: Forward, Predicted Class: Shoulder
# Image: cropped2_60.png, True Class: Left Mirror, Predicted Class: Right Mirror
# Image: cropped4_860.png, True Class: Left Mirror, Predicted Class: Forward
# Image: cropped4_865.png, True Class: Left Mirror, Predicted Class: Shoulder
# Image: cropped4_870.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_100.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_105.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_110.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_1125.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_1130.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_1135.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_1140.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_115.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_1240.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_1245.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_1635.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_1640.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_1840.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_1845.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_2495.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_2500.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_2505.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_2695.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_2700.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_3110.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_3115.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_3170.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_3175.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_3230.png, True Class: Left Mirror, Predicted Class: Eyes Closed
# Image: croppedm_3235.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_605.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_610.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_615.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_620.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_625.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_630.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_635.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_670.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_675.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_680.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_685.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_730.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_735.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_740.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_745.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_800.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_805.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_810.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_815.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_820.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_95.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_960.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_965.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_970.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_975.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_980.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_985.png, True Class: Left Mirror, Predicted Class: Forward
# Image: cropped_470.png, True Class: Left Mirror, Predicted Class: Forward
# Image: cropped_475.png, True Class: Left Mirror, Predicted Class: Forward
# Image: cropped_480.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: cropped_485.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: cropped_490.png, True Class: Left Mirror, Predicted Class: Right Mirror
# Image: cropped_510.png, True Class: Left Mirror, Predicted Class: Right Mirror
# Image: cropped_515.png, True Class: Left Mirror, Predicted Class: Right Mirror
# Image: cropped_520.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: cropped4_505.png, True Class: Radio, Predicted Class: Speedometer
# Image: cropped4_510.png, True Class: Radio, Predicted Class: Speedometer
# Image: cropped4_515.png, True Class: Radio, Predicted Class: Speedometer
# Image: cropped4_520.png, True Class: Radio, Predicted Class: Speedometer
# Image: croppedm_0.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_10.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_15.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_1920.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_1925.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_1930.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_20.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_250.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_255.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_260.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_265.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_270.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_350.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_355.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_360.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_3730.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_3735.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_5.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_890.png, True Class: Radio, Predicted Class: Forward
# Image: cropped4_1185.png, True Class: Rearview, Predicted Class: Speedometer
# Image: cropped4_1190.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_125.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_1280.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_135.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_140.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_2390.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_2395.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_2420.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_2425.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_2515.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_2520.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_2525.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_2815.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_300.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_305.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_320.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_325.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_330.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_3365.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_340.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_3420.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_3425.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_3430.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_345.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_365.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_370.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_3725.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_530.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_535.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_540.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_545.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_550.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_555.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_560.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_565.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_570.png, True Class: Rearview, Predicted Class: Forward
# Image: cropped4_380.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_1500.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_1505.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_1510.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2020.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2025.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2030.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2035.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2040.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2045.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2355.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2360.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2365.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2370.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2545.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2550.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2555.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2560.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2565.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_3320.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_3325.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_3330.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_3745.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_3750.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_3755.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_380.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_385.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_415.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_420.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_425.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_435.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_470.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_475.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_480.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_485.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_490.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_495.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_500.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_580.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_585.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_60.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_65.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_930.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_935.png, True Class: Right Mirror, Predicted Class: Forward
# Image: cropped2_55.png, True Class: Shoulder, Predicted Class: Right Mirror
# Image: croppedm_450.png, True Class: Shoulder, Predicted Class: Rearview
# Image: croppedm_460.png, True Class: Shoulder, Predicted Class: Rearview
# Image: cropped_445.png, True Class: Shoulder, Predicted Class: Eyes Closed
# Image: croppedm_1445.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1450.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1455.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1460.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1465.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1470.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1700.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1705.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1710.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1735.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1740.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1745.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1750.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1755.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_200.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_205.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_210.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_215.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_220.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_225.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_230.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_2460.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_2465.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_2575.png, True Class: Speedometer, Predicted Class: Forward

# %%
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import itertools
import torchvision.transforms as transforms
from torchvision import models
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import cv2
import torch.nn as nn

# Define the image transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Define a custom dataset class
class EyeGazeDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.image_paths = []
        self.labels = []

        for label, class_name in enumerate(eyeGazeClasses):
            class_dir = os.path.join(root_dir, class_name)
            for image_name in os.listdir(class_dir):
                self.image_paths.append(os.path.join(class_dir, image_name))
                self.labels.append(label)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        pil_image = Image.fromarray(cv2.cvtColor(cv2.imread(image_path), cv2.COLOR_BGR2RGB))
        width, height = pil_image.size
        cropped_image = pil_image.crop((0, 0, width, 125))  # Crop the top 130 pixels
        image = self.transform(cropped_image)
        label = self.labels[idx]

        return image, label

model_path="MNV3_small_weights_cleaned_100.pth"

model = models.mobilenet_v3_small(pretrained=True)

for param in model.parameters():
    param.requires_grad = False

# Define constants
NUM_CLASSES = 8
INPUT_FEATURES = 576
HIDDEN_FEATURES = 1024
OUTPUT_FEATURES = 1280

# Define the custom classifier
classifier = nn.Sequential(
    nn.Linear(INPUT_FEATURES, HIDDEN_FEATURES, bias=True),
    nn.Hardswish(),
    nn.Dropout(p=0.2, inplace=True),
    nn.Linear(HIDDEN_FEATURES, OUTPUT_FEATURES, bias=True),
    nn.Linear(OUTPUT_FEATURES, NUM_CLASSES, bias=True),  # Output layer with 8 classes
    nn.Softmax(dim=1)
)

# Replace the default classifier with the custom one
model.classifier = classifier
model.load_state_dict(torch.load(model_path))
model.eval()

eyeGazeClasses = ['Eyes Closed', 'Forward', 'Left Mirror', 'Radio', 
                  'Rearview', 'Right Mirror', 'Shoulder', 'Speedometer']
classes_labels=['Eyes Closed', 'Forward', 'Left Mirror', 'Radio', 
                  'Rearview', 'Right Mirror', 'Shoulder', 'Speedometer']

# Function to preprocess the image
def preprocess_image(image_path):
    pil_image = Image.fromarray(cv2.cvtColor(cv2.imread(image_path), cv2.COLOR_BGR2RGB))
    width, height = pil_image.size
    cropped_image = pil_image.crop((0, 0, width, 125))  # Crop the top 130 pixels
    input_image = transform(cropped_image).unsqueeze(0)  # Add batch dimension
    return input_image, pil_image

# Define the dataloader for the testing data
test_folder_path = "Test Data"
test_dataset = EyeGazeDataset(root_dir=test_folder_path, transform=transform)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False)

def plot_confusion_matrix(model, dataloader, num_classes, class_labels):
    # Set the model to evaluation mode
    model.eval()

    # Initialize lists to store the true and predicted labels
    true_labels = []
    pred_labels = []

    # Iterate over the validation dataset
    with torch.no_grad():
        for images, labels in dataloader:

            # Move the input tensor to the same device as the model weights
            if next(model.parameters()).is_cuda:
                images = images.cuda()

            # Forward pass
            outputs = model(images)

            # Get the predicted labels
            _, predicted = torch.max(outputs.data, 1)


            # Store the true and predicted labels
            true_labels += labels.cpu().numpy().tolist()
            pred_labels += predicted.cpu().numpy().tolist()

    # Compute the confusion matrix
    cm = confusion_matrix(true_labels, pred_labels)
    
    # Plot the confusion matrix
    plt.figure(figsize=(10, 7))
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted label')
    plt.ylabel('True label')
    plt.imshow(cm, cmap='Blues')
    plt.xticks(range(num_classes),class_labels)
    plt.yticks(range(num_classes),class_labels)
    cm = np.around(cm.astype('float')/cm.sum(axis=1)[:,np.newaxis],decimals=2)
    plt.colorbar()
    plt.clim(0, max(cm.max(), cm.sum()))
    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
      color = "white" if cm[i, j] > thresh else "black"
      plt.text(j, i, cm[i, j], horizontalalignment="center", color=color)


    plt.tight_layout()
    plt.ylim(num_classes, -0.5)
    plt.imshow(cm, cmap='Blues', vmin=0, vmax=1)


# Plot the confusion matrix using the test data
plot_confusion_matrix(model, test_dataloader,8,eyeGazeClasses)
# Out:
# C:\Users\AS-GP\AppData\Local\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\AS-GP\AppData\Local\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V3_Small_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V3_Small_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import itertools
import torchvision.transforms as transforms
from torchvision import models
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import cv2
import torch.nn as nn

# Define the image transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Define a custom dataset class
class EyeGazeDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.image_paths = []
        self.labels = []

        for label, class_name in enumerate(eyeGazeClasses):
            class_dir = os.path.join(root_dir, class_name)
            for image_name in os.listdir(class_dir):
                self.image_paths.append(os.path.join(class_dir, image_name))
                self.labels.append(label)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        pil_image = Image.fromarray(cv2.cvtColor(cv2.imread(image_path), cv2.COLOR_BGR2RGB))
        width, height = pil_image.size
        cropped_image = pil_image.crop((0, 0, width, 135))  # Crop the top 130 pixels
        image = self.transform(cropped_image)
        label = self.labels[idx]

        return image, label

model_path="MNV3_small_weights_cleaned_500.pth"

model = models.mobilenet_v3_small(pretrained=True)

for param in model.parameters():
    param.requires_grad = False

# Define constants
NUM_CLASSES = 8
INPUT_FEATURES = 576
HIDDEN_FEATURES = 1024
OUTPUT_FEATURES = 1280

# Define the custom classifier
classifier = nn.Sequential(
    nn.Linear(INPUT_FEATURES, HIDDEN_FEATURES, bias=True),
    nn.Hardswish(),
    nn.Dropout(p=0.2, inplace=True),
    nn.Linear(HIDDEN_FEATURES, OUTPUT_FEATURES, bias=True),
    nn.Linear(OUTPUT_FEATURES, NUM_CLASSES, bias=True),  # Output layer with 8 classes
    nn.Softmax(dim=1)
)

# Replace the default classifier with the custom one
model.classifier = classifier
model.load_state_dict(torch.load(model_path))
model.eval()

eyeGazeClasses = ['Eyes Closed', 'Forward', 'Left Mirror', 'Radio', 
                  'Rearview', 'Right Mirror', 'Shoulder', 'Speedometer']
classes_labels=['Eyes Closed', 'Forward', 'Left Mirror', 'Radio', 
                  'Rearview', 'Right Mirror', 'Shoulder', 'Speedometer']

# Function to preprocess the image
def preprocess_image(image_path):
    pil_image = Image.fromarray(cv2.cvtColor(cv2.imread(image_path), cv2.COLOR_BGR2RGB))
    width, height = pil_image.size
    cropped_image = pil_image.crop((0, 0, width, 135))  # Crop the top 130 pixels
    input_image = transform(cropped_image).unsqueeze(0)  # Add batch dimension
    return input_image, pil_image

# Define the dataloader for the testing data
test_folder_path = "Final Test Data"
test_dataset = EyeGazeDataset(root_dir=test_folder_path, transform=transform)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False)

def plot_confusion_matrix(model, dataloader, num_classes, class_labels):
    # Set the model to evaluation mode
    model.eval()

    # Initialize lists to store the true and predicted labels
    true_labels = []
    pred_labels = []

    # Iterate over the validation dataset
    with torch.no_grad():
        for images, labels in dataloader:

            # Move the input tensor to the same device as the model weights
            if next(model.parameters()).is_cuda:
                images = images.cuda()

            # Forward pass
            outputs = model(images)

            # Get the predicted labels
            _, predicted = torch.max(outputs.data, 1)


            # Store the true and predicted labels
            true_labels += labels.cpu().numpy().tolist()
            pred_labels += predicted.cpu().numpy().tolist()

    # Compute the confusion matrix
    cm = confusion_matrix(true_labels, pred_labels)
    
    # Plot the confusion matrix
    plt.figure(figsize=(10, 8))
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted label')
    plt.ylabel('True label')
    plt.imshow(cm, cmap='Blues')
    plt.xticks(range(num_classes),class_labels)
    plt.yticks(range(num_classes),class_labels)
    cm = np.around(cm.astype('float')/cm.sum(axis=1)[:,np.newaxis],decimals=2)
    plt.colorbar()
    plt.clim(0, max(cm.max(), cm.sum()))
    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
      color = "white" if cm[i, j] > thresh else "black"
      plt.text(j, i, cm[i, j], horizontalalignment="center", color=color)


    plt.tight_layout()
    plt.ylim(num_classes, -0.5)
    plt.imshow(cm, cmap='Blues', vmin=0, vmax=1)


# Plot the confusion matrix using the test data
plot_confusion_matrix(model, test_dataloader,8,eyeGazeClasses)
# Out:
# C:\Users\AS-GP\AppData\Local\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\AS-GP\AppData\Local\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V3_Small_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V3_Small_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
import os
import torchvision.transforms as transforms
import cv2

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])


def preprocess_image(image_path):
    pil_image = Image.fromarray(cv2.cvtColor(cv2.imread(image_path), cv2.COLOR_BGR2RGB))
    width, height = pil_image.size
    cropped_image = pil_image.crop((0, 0, width, 155))
    input_image = transform(cropped_image).unsqueeze(0)  # Add batch dimension
    return input_image

#the test images
test_dir = "Test Data"

# counters for accuracy calculation
total_images = 0
correct_predictions = 0

accurately_detected_images = []
misclassified_images = []

for class_name in os.listdir(test_dir):
    class_dir = os.path.join(test_dir, class_name)
    if os.path.isdir(class_dir):
        for image_name in os.listdir(class_dir):
            image_path = os.path.join(class_dir, image_name)
            input_image = preprocess_image(image_path)

            #make prediction
            output = model(input_image)
            _, predicted = torch.max(output.data, 1)
            predicted_class = eyeGazeClasses[predicted.item()]

            #if the prediction is correct
            total_images += 1
            if predicted_class == class_name:
                correct_predictions += 1
                accurately_detected_images.append((image_name, class_name, predicted_class))
            else:
                misclassified_images.append((image_name, class_name, predicted_class))

#calculate accuracy
accuracy = correct_predictions / total_images * 100

#results
print(f"Accuracy: {accuracy:.2f}%")
print("Accurately Detected Images:")
for image_name, true_class, predicted_class in accurately_detected_images:
    print(f"Image: {image_name}, True Class: {true_class}, Predicted Class: {predicted_class}")
print("Misclassified Images:")
for image_name, true_class, predicted_class in misclassified_images:
    print(f"Image: {image_name}, True Class: {true_class}, Predicted Class: {predicted_class}")
# Out:
# Accuracy: 69.81%
# Accurately Detected Images:
# Image: cropped3_75.png, True Class: Eyes Closed, Predicted Class: Eyes Closed
# Image: cropped4_830.png, True Class: Eyes Closed, Predicted Class: Eyes Closed
# Image: croppedm_120.png, True Class: Eyes Closed, Predicted Class: Eyes Closed
# Image: croppedm_1250.png, True Class: Eyes Closed, Predicted Class: Eyes Closed
# Image: croppedm_3120.png, True Class: Eyes Closed, Predicted Class: Eyes Closed
# Image: croppedm_3180.png, True Class: Eyes Closed, Predicted Class: Eyes Closed
# Image: cropped_670.png, True Class: Eyes Closed, Predicted Class: Eyes Closed
# Image: cropped_690.png, True Class: Eyes Closed, Predicted Class: Eyes Closed
# Image: cropped2_0.png, True Class: Forward, Predicted Class: Forward
# Image: cropped2_10.png, True Class: Forward, Predicted Class: Forward
# Image: cropped2_100.png, True Class: Forward, Predicted Class: Forward
# Image: cropped2_105.png, True Class: Forward, Predicted Class: Forward
# Image: cropped2_110.png, True Class: Forward, Predicted Class: Forward
# Image: cropped2_115.png, True Class: Forward, Predicted Class: Forward
# Image: cropped2_125.png, True Class: Forward, Predicted Class: Forward
# Image: cropped2_135.png, True Class: Forward, Predicted Class: Forward
# Image: cropped2_15.png, True Class: Forward, Predicted Class: Forward
# Image: cropped2_150.png, True Class: Forward, Predicted Class: Forward
# Image: cropped2_155.png, True Class: Forward, Predicted Class: Forward
# Image: cropped2_160.png, True Class: Forward, Predicted Class: Forward
# Image: cropped2_20.png, True Class: Forward, Predicted Class: Forward
# Image: cropped2_35.png, True Class: Forward, Predicted Class: Forward
# Image: cropped2_40.png, True Class: Forward, Predicted Class: Forward
# Image: cropped2_45.png, True Class: Forward, Predicted Class: Forward
# Image: cropped2_5.png, True Class: Forward, Predicted Class: Forward
# Image: cropped2_70.png, True Class: Forward, Predicted Class: Forward
# Image: cropped2_75.png, True Class: Forward, Predicted Class: Forward
# Image: cropped2_80.png, True Class: Forward, Predicted Class: Forward
# Image: cropped2_85.png, True Class: Forward, Predicted Class: Forward
# Image: cropped2_95.png, True Class: Forward, Predicted Class: Forward
# Image: cropped3_25.png, True Class: Forward, Predicted Class: Forward
# Image: cropped3_35.png, True Class: Forward, Predicted Class: Forward
# Image: cropped3_40.png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_1110(1).png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_1110.png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_1115(1).png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_1115.png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_1175(1).png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_1175.png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_1180(1).png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_1180.png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_155(1).png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_155.png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_315(1).png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_315.png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_350(1).png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_350.png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_355(1).png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_355.png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_485(1).png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_485.png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_490.png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_60.png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_615.png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_620.png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_65.png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_680.png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_710.png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_740.png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_745.png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_765.png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_770.png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_775.png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_780.png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_790.png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_80.png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_835.png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_845.png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_85.png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_850.png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_855.png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_90.png, True Class: Forward, Predicted Class: Forward
# Image: cropped4_945.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1000.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1005.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1010.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1015.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1020.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1025.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1030.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1035.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1040.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1045.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1050.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1055.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1060.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1065.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1075.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1080.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1095.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1100.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1105.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1110.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1115.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1120.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1145.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1150.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1155.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1160.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1165.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1170.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1175.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1180.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1185.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1190.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1195.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1200.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1205.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1210.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1215.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1220.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1225.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1230.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1235.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1255.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1260.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1265.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1270.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1275.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1285.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1295.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_130.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1300.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1305.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1310.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1315.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1320.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1325.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1330.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1335.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1340.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1345.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1350.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1355.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1360.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1365.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1370.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1375.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1380.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1385.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1390.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1395.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1400.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1405.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1410.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1415.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1420.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1425.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1430.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1435.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1440.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_145.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1475.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1480.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1485.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1490.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1495.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_150.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1520.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1525.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1530.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1535.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1540.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1545.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_155.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1550.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1555.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1560.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1565.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1570.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1575.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1580.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1585.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1590.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1595.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1600.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1605.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1610.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1615.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1620.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1625.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1650.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1655.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1690.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1695.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1715.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1720.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1725.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1730.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1760.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1765.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1770.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1775.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1780.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1785.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1790.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1795.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1800.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1805.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1810.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1815.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1820.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1825.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1830.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_185.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1855.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1860.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1865.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1870.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1875.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1880.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1885.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1890.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1895.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_190.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1900.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1905.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1910.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1915.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1940.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1945.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_195.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1950.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1955.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1960.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1965.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1970.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1975.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1980.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1985.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1990.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1995.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2000.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2005.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2010.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2055.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2060.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2065.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2070.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2075.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2080.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2085.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2090.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2095.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2100.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2105.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2110.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2115.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2120.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2125.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2130.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2135.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2140.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2145.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2150.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2155.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2160.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2165.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2170.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2175.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2180.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2185.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2190.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2195.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2200.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2205.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2210.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2215.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2220.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2225.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2235.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2240.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2245.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2250.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2255.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2260.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2265.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2270.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2275.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2280.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2285.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2290.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2295.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2300.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2305.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2310.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2315.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2320.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2325.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2330.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2335.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2340.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2345.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_235.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2350.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2375.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2380.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2385.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_240.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2410.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2415.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2430.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2435.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2440.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2445.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_245.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2450.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2470.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2475.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2480.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2485.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2490.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_25.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2530.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2535.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2540.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2580.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2585.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2590.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2595.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2600.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2605.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2610.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2615.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2620.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2625.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2630.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2635.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2640.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2645.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2650.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2655.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2665.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2670.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2675.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2680.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2685.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2710.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2715.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2730.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2735.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2740.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2745.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2750.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2755.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2760.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2765.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2770.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2775.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2780.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2785.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2790.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2795.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2800.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2805.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2810.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2830.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2835.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2840.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2845.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2855.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2860.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2865.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2870.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2875.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2880.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2885.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2890.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2895.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_290.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2900.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2915.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2920.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2925.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2930.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2935.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2940.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2945.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_295.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2950.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2955.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2960.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2965.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2970.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2975.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2980.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2985.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2990.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_2995.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_30.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3000.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3005.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3010.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3015.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3020.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3025.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3030.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3035.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3040.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3045.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3050.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3055.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3060.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3065.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3070.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3075.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3080.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3085.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3090.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3095.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_310.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3100.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3130.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3135.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3140.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_315.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3155.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3160.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3165.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3185.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3190.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3195.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3200.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3205.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3210.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3215.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3220.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3225.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3245.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3250.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3255.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3260.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3265.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3270.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3275.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3280.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3285.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3290.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3295.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3300.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3305.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3310.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3340.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3345.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_335.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3350.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3355.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3360.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3370.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3375.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3380.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3385.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3390.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3395.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3400.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3405.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3410.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3415.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3440.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3445.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3450.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3455.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3460.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3465.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3470.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3475.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3480.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3485.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3490.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3495.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_35.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3500.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3505.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3510.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3515.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3520.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3525.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3530.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3535.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3540.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3545.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3550.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3555.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3560.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3565.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3570.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3575.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3580.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3585.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3590.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3595.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3600.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3615.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3620.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3625.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3630.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3635.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3640.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3645.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3650.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3655.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3660.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3665.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3670.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3680.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3685.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3690.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3695.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3700.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3705.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3710.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3715.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3720.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_375.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3760.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3765.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3770.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3775.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3780.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3785.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3820.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_3830.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_395.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_40.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_45.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_50.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_595.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_650.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_655.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_695.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_700.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_705.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_710.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_715.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_720.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_75.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_755.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_760.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_765.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_770.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_775.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_780.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_785.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_80.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_830.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_835.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_840.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_845.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_85.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_850.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_855.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_860.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_865.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_870.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_875.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_880.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_885.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_90.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_905.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_910.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_915.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_920.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_945.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_950.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_995.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_0.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_10.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_100.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_105.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_115.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_120.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_125.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_130.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_135.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_140.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_145.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_15.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_150.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_155.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_160.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_165.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_170.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_175.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_180.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_185.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_190.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_195.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_20.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_200.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_205.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_210.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_220.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_225.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_230.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_235.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_240.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_245.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_25.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_250.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_255.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_260.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_265.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_270.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_290.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_295.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_30.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_305.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_335.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_340.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_35.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_350.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_355.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_360.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_365.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_370.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_375.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_400.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_405.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_410.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_45.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_460.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_465.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_495.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_5.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_50.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_500.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_505.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_525.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_530.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_535.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_540.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_545.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_55.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_555.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_560.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_565.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_570.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_575.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_580.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_585.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_590.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_595.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_60.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_600.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_605.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_610.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_65.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_70.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_75.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_80.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_85.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_90.png, True Class: Forward, Predicted Class: Forward
# Image: cropped_95.png, True Class: Forward, Predicted Class: Forward
# Image: croppedm_1840.png, True Class: Left Mirror, Predicted Class: Left Mirror
# Image: cropped2_55.png, True Class: Shoulder, Predicted Class: Shoulder
# Image: croppedm_455.png, True Class: Shoulder, Predicted Class: Shoulder
# Image: croppedm_460.png, True Class: Shoulder, Predicted Class: Shoulder
# Image: cropped_445.png, True Class: Shoulder, Predicted Class: Shoulder
# Image: croppedm_1750.png, True Class: Speedometer, Predicted Class: Speedometer
# Misclassified Images:
# Image: cropped2_180.png, True Class: Eyes Closed, Predicted Class: Shoulder
# Image: cropped2_185.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped2_265.png, True Class: Eyes Closed, Predicted Class: Rearview
# Image: cropped2_270.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped2_275.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped2_280.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped2_285.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped2_290.png, True Class: Eyes Closed, Predicted Class: Forward
# Image: cropped2_350.png, True Class: Eyes Closed, Predicted Class: Speedometer
# ...
# Image: cropped4_815.png, True Class: Forward, Predicted Class: Rearview
# Image: cropped4_820.png, True Class: Forward, Predicted Class: Rearview
# Image: cropped4_940.png, True Class: Forward, Predicted Class: Left Mirror
# Image: croppedm_1070.png, True Class: Forward, Predicted Class: Speedometer
# Image: croppedm_1085.png, True Class: Forward, Predicted Class: Speedometer
# Image: croppedm_1090.png, True Class: Forward, Predicted Class: Speedometer
# Image: croppedm_3125.png, True Class: Forward, Predicted Class: Left Mirror
# Image: croppedm_3145.png, True Class: Forward, Predicted Class: Speedometer
# Image: croppedm_3150.png, True Class: Forward, Predicted Class: Speedometer
# Image: croppedm_3605.png, True Class: Forward, Predicted Class: Speedometer
# Image: croppedm_3610.png, True Class: Forward, Predicted Class: Speedometer
# Image: croppedm_600.png, True Class: Forward, Predicted Class: Left Mirror
# Image: croppedm_645.png, True Class: Forward, Predicted Class: Left Mirror
# Image: croppedm_660.png, True Class: Forward, Predicted Class: Left Mirror
# Image: croppedm_790.png, True Class: Forward, Predicted Class: Left Mirror
# Image: cropped_215.png, True Class: Forward, Predicted Class: Rearview
# Image: cropped_300.png, True Class: Forward, Predicted Class: Speedometer
# Image: cropped_310.png, True Class: Forward, Predicted Class: Speedometer
# Image: cropped_315.png, True Class: Forward, Predicted Class: Speedometer
# Image: cropped_320.png, True Class: Forward, Predicted Class: Speedometer
# Image: cropped_345.png, True Class: Forward, Predicted Class: Shoulder
# Image: cropped_455.png, True Class: Forward, Predicted Class: Left Mirror
# Image: cropped_550.png, True Class: Forward, Predicted Class: Shoulder
# Image: cropped2_60.png, True Class: Left Mirror, Predicted Class: Shoulder
# Image: cropped4_860.png, True Class: Left Mirror, Predicted Class: Forward
# Image: cropped4_865.png, True Class: Left Mirror, Predicted Class: Shoulder
# Image: cropped4_870.png, True Class: Left Mirror, Predicted Class: Shoulder
# Image: croppedm_100.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_105.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_110.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_1125.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_1130.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_1135.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_1140.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_115.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_1240.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_1245.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_1635.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_1640.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_1845.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_2495.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_2500.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_2505.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_2695.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_2700.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_3110.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_3115.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_3170.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_3175.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_3230.png, True Class: Left Mirror, Predicted Class: Forward
# Image: croppedm_3235.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_605.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_610.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_615.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_620.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_625.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_630.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_635.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_670.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_675.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_680.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_685.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_730.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_735.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_740.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_745.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_800.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_805.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_810.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_815.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_820.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_95.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_960.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_965.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_970.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_975.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_980.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: croppedm_985.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: cropped_470.png, True Class: Left Mirror, Predicted Class: Forward
# Image: cropped_475.png, True Class: Left Mirror, Predicted Class: Rearview
# Image: cropped_480.png, True Class: Left Mirror, Predicted Class: Forward
# Image: cropped_485.png, True Class: Left Mirror, Predicted Class: Forward
# Image: cropped_490.png, True Class: Left Mirror, Predicted Class: Forward
# Image: cropped_510.png, True Class: Left Mirror, Predicted Class: Shoulder
# Image: cropped_515.png, True Class: Left Mirror, Predicted Class: Right Mirror
# Image: cropped_520.png, True Class: Left Mirror, Predicted Class: Forward
# Image: cropped4_505.png, True Class: Radio, Predicted Class: Speedometer
# Image: cropped4_510.png, True Class: Radio, Predicted Class: Speedometer
# Image: cropped4_515.png, True Class: Radio, Predicted Class: Speedometer
# Image: cropped4_520.png, True Class: Radio, Predicted Class: Speedometer
# Image: croppedm_0.png, True Class: Radio, Predicted Class: Speedometer
# Image: croppedm_10.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_15.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_1920.png, True Class: Radio, Predicted Class: Speedometer
# Image: croppedm_1925.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_1930.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_20.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_250.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_255.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_260.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_265.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_270.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_350.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_355.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_360.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_3730.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_3735.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_5.png, True Class: Radio, Predicted Class: Forward
# Image: croppedm_890.png, True Class: Radio, Predicted Class: Forward
# Image: cropped4_1185.png, True Class: Rearview, Predicted Class: Forward
# Image: cropped4_1190.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_125.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_1280.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_135.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_140.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_2390.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_2395.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_2420.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_2425.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_2515.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_2520.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_2525.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_2815.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_300.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_305.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_320.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_325.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_330.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_3365.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_340.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_3420.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_3425.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_3430.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_345.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_365.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_370.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_3725.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_530.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_535.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_540.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_545.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_550.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_555.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_560.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_565.png, True Class: Rearview, Predicted Class: Forward
# Image: croppedm_570.png, True Class: Rearview, Predicted Class: Forward
# Image: cropped4_380.png, True Class: Right Mirror, Predicted Class: Speedometer
# Image: croppedm_1500.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_1505.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_1510.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2020.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2025.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2030.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2035.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2040.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2045.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2355.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2360.png, True Class: Right Mirror, Predicted Class: Left Mirror
# Image: croppedm_2365.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2370.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2545.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2550.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2555.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2560.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_2565.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_3320.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_3325.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_3330.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_3745.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_3750.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_3755.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_380.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_385.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_415.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_420.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_425.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_435.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_470.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_475.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_480.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_485.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_490.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_495.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_500.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_580.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_585.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_60.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_65.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_930.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_935.png, True Class: Right Mirror, Predicted Class: Forward
# Image: croppedm_450.png, True Class: Shoulder, Predicted Class: Rearview
# Image: croppedm_1445.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1450.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1455.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1460.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1465.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1470.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1700.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1705.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1710.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1735.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1740.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1745.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_1755.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_200.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_205.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_210.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_215.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_220.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_225.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_230.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_2460.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_2465.png, True Class: Speedometer, Predicted Class: Forward
# Image: croppedm_2575.png, True Class: Speedometer, Predicted Class: Forward

# %%
Image: croppeda1_300.png, True Class: Rearview, Predicted Class: Rearview
Image: croppeda2_1870.png, True Class: Rearview, Predicted Class: Rearview
Image: croppeda2_1875.png, True Class: Rearview, Predicted Class: Rearview
Image: croppeda2_1890.png, True Class: Rearview, Predicted Class: Rearview
Image: croppeda2_1905.png, True Class: Rearview, Predicted Class: Rearview
Image: croppeda2_1930.png, True Class: Rearview, Predicted Class: Rearview
Image: croppedm1_105.png, True Class: Rearview, Predicted Class: Rearview
Image: croppedm1_110.png, True Class: Rearview, Predicted Class: Rearview
Image: croppedm1_120.png, True Class: Rearview, Predicted Class: Rearview
Image: croppedm1_130.png, True Class: Rearview, Predicted Class: Rearview
Image: croppedm1_75.png, True Class: Rearview, Predicted Class: Rearview
Image: croppedm1_80.png, True Class: Rearview, Predicted Class: Rearview
Image: croppedm1_95.png, True Class: Rearview, Predicted Class: Rearview
Image: croppedy1_210.png, True Class: Rearview, Predicted Class: Rearview

# %%
import cv2
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
# Preprocess the image (assuming frame is a path or numpy array)
frame = "Test Data/Speedometer/croppedm_225.png"
pil_image = Image.fromarray(cv2.cvtColor(cv2.imread(frame), cv2.COLOR_BGR2RGB))
width, height = pil_image.size
cropped_image = pil_image.crop((0, 0, width, 120))
input_image = transform(cropped_image).unsqueeze(0)  # Add batch dimension

# Make prediction
output = model(input_image)

# Get the predicted class with the highest probability
_, predicted = torch.max(output.data, 1)

# Print the predicted class
print(f"Predicted Class: {eyeGazeClasses[predicted.item()]}")
print(output)
# Show the image (assuming it's a color image)
plt.imshow(pil_image)
plt.title(f"Predicted Class: {eyeGazeClasses[predicted.item()]}")
plt.show()
# Out:
# Predicted Class: Forward
# tensor([[4.0810e-11, 9.8864e-01, 3.3039e-03, 7.2312e-16, 8.3034e-08, 2.9905e-11,
#          1.7674e-15, 8.0600e-03]], grad_fn=<SoftmaxBackward0>)
